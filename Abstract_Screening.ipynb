# %% [markdown]
# ### Install the Python SDK
#
# The Python SDK for the Gemini API, is contained in the [`google-generativeai`](https://pypi.org/project/google-generativeai/) package. Install the dependency using pip:

# %%
# !pip install -q -U google-generativeai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 2.6 MB/s eta 0:00:00

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.6.2)

# %%
# !pip install bibtexparser
# Out:
# Collecting bibtexparser
#   Downloading bibtexparser-1.4.1.tar.gz (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 1.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from bibtexparser) (3.1.2)
# Building wheels for collected packages: bibtexparser
#   Building wheel for bibtexparser (setup.py) ... done
#   Created wheel for bibtexparser: filename=bibtexparser-1.4.1-py3-none-any.whl size=43253 sha256=4a15e05166d5706de9c5b253ad5320689678173090f9c7e848ae92b6b0d9a622
#   Stored in directory: /root/.cache/pip/wheels/08/c6/c3/56e639fab68d1fdbf13ea147636d9795ccdbd3c1d3178d1332
# Successfully built bibtexparser
# Installing collected packages: bibtexparser
# Successfully installed bibtexparser-1.4.1

# %% [markdown]
# ### Import packages

# %% [markdown]
# Import the necessary packages.

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
# Used to securely store your API key
from google.colab import userdata

# %%
genai.configure(api_key=userdata.get('google-generativeai-api-key'))

# %% [markdown]
# ## List models
#
# Now you're ready to call the Gemini API. Use `list_models` to see the available Gemini models:
#
# * `gemini-pro`: optimized for text-only prompts.
# * `gemini-pro-vision`: optimized for text-and-images prompts.

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-flash
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-latest
# models/gemini-1.5-pro
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %% [markdown]
# ## Generate text from text inputs
#
# For text-only prompts, use the `gemini-pro` model:

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
import bibtexparser
import pandas as pd

# %%
# Define the path to your BibTeX file and Excel file
bibtex_file_path = '/content/savedrecs (1).bib'
excel_file_path = 'output_data.xlsx'

# Create a function to extract title, abstract, and DOI from each entry
def extract_info(entry):
    title = entry.get('title', '')
    abstract = entry.get('abstract', '')
    keywords = entry.get('keywords', '')
    doi = entry.get('doi', '')
    Type = entry.get('type','')
    keywordsplus = entry.get('keywords-plus',)



    return title, abstract, keywords,doi,Type,keywordsplus

# Open and parse the BibTeX file
with open(bibtex_file_path, 'r', encoding='utf-8') as bibtex_file:
    bibtex_database = bibtexparser.load(bibtex_file)

# Create a list to store the extracted information
entries_info = []

# Iterate through the BibTeX entries and extract information
for entry in bibtex_database.entries:
    title, abstract, keywords, doi,Type,keywordsplus= extract_info(entry)
    entries_info.append({'Title': title, 'Abstract': abstract, 'keywords': keywords, 'doi': doi,'type':Type,'keywordsplus':keywordsplus})
     #entries_info.append({'Title': title, 'Abstract': abstract})

# Create a DataFrame from the extracted information
df = pd.DataFrame(entries_info)

# Save the DataFrame to an Excel file
df.to_excel(excel_file_path, index=False)

print(f'Data has been successfully saved to "{excel_file_path}".')
# Out:
# Data has been successfully saved to "output_data.xlsx".

# %%
df = pd.read_excel('/content/output_data.xlsx')

# %%
df
# Out:
#                                                  Title  \
# 0    Distribution and partitioning of pyrethroid in...
# 1    Drought versus flood: What matters more to the...
# 2    Evapotranspiration of Irrigated Crops under Wa...
# 3    Arabic Semantic Similarity Approach for Farmer...
# 4    Functional homoeologous alleles of <i>CONSTANS...
# ..                                                 ...
# 318  Evaluation of an intelligent artificial climat...
# 319  Can crop yields be secured while reducing phos...
# 320  Geo-CropSim: A Geo-spatial crop simulation mod...
# 321  Hymenopteran Parasitoids of Aphid Pests within...
# 322  Crop phenology reshapes the food-safety landsc...
#
#                                               Abstract  \
# 0    Pyrethroid insecticides are widely applied due...
# 1    Recent climate change has brought new patterns...
# 2    Future changes in crop evapotranspiration (ETc...
# 3    Semantic similarity is applied for many areas ...
# 4    Key message Two CO paralogs in Brassica napus ...
# ..                                                 ...
# 318  Background The superposition of COVID-19 and c...
# 319  Context: A balanced phosphorus (P) use in agri...
# 320  Remote sensing derived datasets (e.g. Leaf Are...
# 321  Simple Summary\nIn grain crops, aphids are imp...
# 322  Understanding the behavioural adjustments of w...
#
#                                               keywords  \
# 0    Pyrethroid insecticides; Surface soil; Surface...
# 1    drought; farming system; flood; normalized dif...
# 2    climate change; ensemble; CropSyst; irrigation...
# 3    Semantic similarity; latent semantic analysis;...
# 4                                                  NaN
# ..                                                 ...
# 318  Intelligent artificial climate chamber; Enviro...
# 319  Long-term experiment; Olsen-P contents; P avai...
# 320  Crop yields; Evapotranspiration; LAI; Emergenc...
# 321  agriculture; grains; Aphididae; Aphidiinae; Di...
# 322  agricultural landscape; behavioural plasticity...
#
#                                  doi                   type  \
# 0       10.1016/j.envint.2021.106736                Article
# 1                  10.1002/hyp.14978                Article
# 2              10.3390/atmos13020163                Article
# 3                                NaN                Article
# 4         10.1007/s00122-021-03896-x  Article; Early Access
# ..                               ...                    ...
# 318       10.1186/s13007-022-00916-9                Article
# 319        10.1016/j.fcr.2023.109185  Article; Early Access
# 320  10.1016/j.isprsjprs.2021.10.024  Article; Early Access
# 321          10.3390/insects12010044                Article
# 322          10.1111/1365-2664.14581  Article; Early Access
#
#                                           keywordsplus
# 0    RISK-ASSESSMENT; PESTICIDES; SEDIMENT; WATER; ...
# 1    SCALE IRRIGATION SYSTEMS; AGRICULTURAL DROUGHT...
# 2    CLIMATE-CHANGE IMPACTS; RISING CO2; RIVER-BASI...
# 3                                            MAPREDUCE
# 4    FLOWERING-LOCUS-T; TIME GENE CONSTANS; NATURAL...
# ..                                                 ...
# 318                   PLANT PHENOMICS; PLATFORM; YIELD
# 319  AGRICULTURAL SOILS; STARTER PHOSPHORUS; MANAGE...
# 320  LEAF-AREA INDEX; REMOTE-SENSING DATA; POTENTIA...
# 321  DIAERETIELLA-RAPAE HYMENOPTERA; HEMIPTERA APHI...
# 322  HABITAT SELECTION; RESOURCE WAVES; PREDATION R...
#
# [323 rows x 6 columns]

# %%
selected_columns = df[['Title','Abstract']].values.tolist()

# %%
selected_columns
# Out:
# [['Distribution and partitioning of pyrethroid insecticides in agricultural\nlands: Critical influencing factors',
#   'Pyrethroid insecticides are widely applied due to the broad spectrum and\nhigh efficiency in pest control and detected in various environmental\nmedia, but the key factor affecting their occurrence and distribution in\nagricultural lands is still not clear. Here, we measured pyrethroid\nresidues in 644 surface soil and 630 surface water samples and\nquantified the impacts of various factors on the distribution and\npartition of pyrethroids through a large-scale field study in Southeast\nChina during 2015-2017. The pyrethroid residues were widely detected in\nthe studied areas, and the mean concentration of seven individual\npyrethroids in surface soil and water ranged from 0.10 (cyfluthrin,\n(CYF)) to 12.14 ng/g (bifenthrin, (BIF)) and 0.18 (CYF) to 3.36 mu g/L\n(BIF) respectively, which were higher than other regions in China and\nsome other countries. Using a generalized linear model coupled with\ndominance analysis, we found that the crop type and season were\nsignificantly associated with pyrethroid residues in surface soil and\nwater (p < 0.05). The crop difference dominated the variances of the\ndistribution of pyrethroid residues in the surface soil and water with a\ncontribution of more than 55\\% and followed by the factor of season\ndifference. The findings provide new insight into the distribution and\npartitioning of pyrethroids in agricultural lands and insecticide\ncontrol on ecological safety and public health.'],
#  ['Drought versus flood: What matters more to the performance of Sahel\nfarming systems?',
#   "Recent climate change has brought new patterns of extreme events in\nterms of both drought and heavy rainfall to the drought-prone African\nSahel. The effects of these recent extreme events on the performance of\nthe Sahel farming systems are still weakly investigated. This study aims\nat assessing effects of droughts versus floods on crop yield levels and\nlosses, focusing on the so-called recovery period, particularly\n2001-2020. A newly developed productivity-drought condition index (PDCI)\nis utilized to assess agricultural productivity as related to drought or\nflood in a highly vulnerable region, that is, the Sudanese Sahel. Four\nfarming systems, namely traditional rainfed, mechanized rainfed, gravity\nirrigated and spate irrigated systems, with sorghum and millet as staple\nfood crops, are considered. The PDCI is defined as a function of the\nintegrated normalized difference vegetation index (iNDVI) over the\ngrowing season. To address temporal and spatial variabilities, scaling\nof the PDCI is done in two dimensions: space and time. Crop statistics\nare used to derive yield losses. Our results show that both drought and\nflood episodes (seven and six episodes, respectively) can be captured\nusing the PDCI. Drought remains the most relevant risk to Sahel's crop\nproductivity. Some recent large-scale floods led to yield loss. However,\nfloods cause smaller risks to agricultural productivity compared to\ndroughts. Floods may even result in enhanced crop yields. Based upon\nscaling in the time or space domain, ranking the severity of drought\nimpacts on crop yield for individual years from 2001 to 2020 reveals\nleast to slightly different results. Vulnerability to drought depends on\nthe crop type and farming system. Drought effect on crop yield from the\nirrigated sector is clear on individual years but not as a general\nstatistical relationship. The parameter `percentage area under drought'\nexplains around one-third of the variation in the rainfed crop yield.\nThe spate irrigation scheme, the gravity irrigated system and the\nrainfed farmlands experienced respectively 87\\%, 57\\% and 46\\% of area\nunder drought on average. Irrigated systems produce much higher crop\nyields than rainfed systems. The mechanized system is more\ndrought-vulnerable than the traditional system. These results call for\nidentifying agricultural management pathways that recognize the combined\nimplications of both hydrological extremes for the region's food\nsecurity.\nA newly devised productivity-drought condition index (PDCI) based on\nintegrated normalized difference vegetation index (iNDVI) data is used\nto capture the performance of different Sahel farming systems. The\nperformance is evaluated spatially and temporally in a comparative study\nof effects of drought versus floods on crop yield levels and losses\nduring 2001-2020. Our research shows that: Crop productivity of all\nfarming systems is severely affected by drought; Flood events can also\nlead to a decline in productivity, but usually to a much lesser extent;\nThe vulnerability to droughts and floods depends upon the farming system\nand crop type. Our analysis shows that the farming systems in the\nSudanese Sahel have not reverted to conditions that could be described\nas a Sahel recovery. This study calls for agricultural management\ndecisions, which are specific for the different farming systems, in\nresponse to climate variability.image"],
#  ['Evapotranspiration of Irrigated Crops under Warming and Elevated\nAtmospheric CO<sub>2</sub>: What Is the Direction of Change?',
#   'Future changes in crop evapotranspiration (ETc) are of interest to water\nmanagement stakeholders. However, long-term projections are complex and\nmerit further investigation due to uncertainties in climate data,\ndifferential responses of crops to climate and elevated atmospheric CO2,\nand adaptive agricultural management. We conducted factor-control\nsimulation experiments using the process-based CropSyst model and\ninvestigated the contribution of each of these factors. Five major\nirrigated crops in the Columbia Basin Project area of the USA Pacific\nNorthwest were selected as a case study and fifteen general circulation\nmodels (GCM) under two representative concentration pathways (RCP) were\nused as the climate forcing. Results indicated a wide range in ETc\nchange, depending on the time frame, crop type, planting dates, and CO2\nassumptions. Under the 2090s RCP8.5 scenario, ETc changes were\ncrop-specific: +14.3\\% (alfalfa), +8.1\\% (potato), -5.1\\% (dry bean),\n-8.1\\% (corn), and -12.5\\% (spring wheat). Future elevated CO2\nconcentrations decreased ETc for all crops while earlier planting\nincreased ETc for all crops except spring wheat. Changes in reference ET\n(ETo) only partially explains changes in ETc because crop responses are\nan important modulating factor; therefore, caution must be exercised in\ninterpreting ETo changes as a proxy for ETc changes.'],
#  ["Arabic Semantic Similarity Approach for Farmers' Complaints",
#   "Semantic similarity is applied for many areas in Natural Language\nProcessing, such as information retrieval, text classification,\nplagiarism detection, and others. Many researchers used semantic\nsimilarity for English texts, but few used for Arabic due to the\nambiguity of Arabic concepts in both sense and morphology. Therefore,\nthe first contribution in this paper is developing a semantic similarity\napproach between Arabic sentences. Nowadays, the world faces a global\nproblem of coronavirus disease. In light of these circumstances and\ndistancing's imposition, it is difficult for farmers to physically\ncommunicate with agricultural experts to provide advice and find\nsuitable solutions for their agricultural complaints. In addition,\ntraditional practices still are used by most farmers. Thus, our second\ncontribution is helping the farmers solve their Arabic agricultural\ncomplaints using our proposed approach. The Latent Semantic Analysis\napproach is applied to retrieve the most problem-related semantic to a\nfarmer's complaint and find the related solution for the farmer. Two\nmethods are used in this approach as a weighting schema for data\nrepresentation are Term Frequency and Term Frequency-Inverse Document\nFrequency. The proposed model has also classified the big agricultural\ndataset and the submitted farmer complaint according to the crop type\nusing MapReduce Support Vector Machine to improve the performance of\nsemantic similarity results. The proposed approach's performance with\nTerm Frequency-Inverse Document Frequency-based Latent Semantic Analysis\nachieved better than its counterparts with an F-measure of 86.7\\%."],
#  ['Functional homoeologous alleles of <i>CONSTANS</i> contribute to\nseasonal crop type in rapeseed',
#   'Key message Two CO paralogs in Brassica napus were confirmed and shown\ndistinct expression pattern and function in promoting flowering and\nallelic variation s within BnaCO.A10 were found closely associated with\necotype divergence. CONSTANS (CO) is a key gene that responds to\nphotoperiod and in Arabidopsis can promote flowering under long-day (LD)\nconditions. Brassica napus L. is a major oil crop and close relative of\nArabidopsis, and arose via allopolyploidization from the diploids B.\nrapa (A genome) and B. oleracea (C genome). In this study, we confirmed\nthat B. napus has two CO genes located on the A10 (BnaCO.A10) and C9\n(BnaCO.C9) chromosomes. Significant differences in level and temporal\npattern of transcription, as well as in protein function, of these\nhomoeologous may have resulted from sequence variation in the promoter\nas well as in the coding region. Apart from two insertions of 527 bp and\n2002 bp in the promoter of BnaCO.C9 that function as transcriptional\nenhancers, this gene is otherwise highly conserved in both promoter and\ncoding region. However, BnaCO.A10 was classified into two haplotypes and\ntransgene analysis in Arabidopsis and backcross analysis in rapeseed\nindicated that the winter-type haplotype had a greater effect in\npromoting flowering than the spring type. We discuss the contribution of\nCO alleles to species evolution, and for eco-geographic radiation\nfollowing crop domestication, alongside scope for managing this locus in\nfuture breeding.'],
#  ['AiTLAS: Artificial Intelligence Toolbox for Earth Observation',
#   'We propose AiTLAS-an open-source, state-of-the-art toolbox for\nexploratory and predictive analysis of satellite imagery. It implements\na range of deep-learning architectures and models tailored for the EO\ntasks illustrated in this case. The versatility and applicability of the\ntoolbox are showcased in a variety of EO tasks, including image scene\nclassification, semantic image segmentation, object detection, and crop\ntype prediction. These use cases demonstrate the potential of the\ntoolbox to support the complete data analysis pipeline starting from\ndata preparation and understanding, through learning novel models or\nfine-tuning existing ones, using models for making predictions on unseen\nimages, and up to analysis and understanding of the predictions and the\npredictive performance yielded by the models. AiTLAS brings the AI and\nEO communities together by facilitating the use of EO data in the AI\ncommunity and accelerating the uptake of (advanced) machine-learning\nmethods and approaches by EO experts. It achieves this by providing: (1)\nuser-friendly, accessible, and interoperable resources for data analysis\nthrough easily configurable and readily usable pipelines; (2)\nstandardized, verifiable, and reusable data handling, wrangling, and\npre-processing approaches for constructing AI-ready data; (3) modular\nand configurable modeling approaches and (pre-trained) models; and (4)\nstandardized and reproducible benchmark protocols including data and\nmodels.'],
#  ['Effects of Crop Rotation and Topography on Soil Erosion and Nutrient\nLoss under Natural Rainfall Conditions on the Chinese Loess Plateau',
#   'Erosive rainfall results in the loss of both soil and nutrients, which\nindirectly triggers soil deterioration and a reduction in land\nproductivity. However, how rainfall affects runoff, soil erosion, and\nnutrient loss under different crop rotation patterns and topographic\nfactors remains unclear. This experiment observed nine runoff-erosion\nplots on the Chinese Loess Plateau (CLP) from 2019 to 2020 to determine\nthe effects of crop type, rotation pattern, and slope gradient and\nlength on runoff, soil erosion, and nutrient loss. Runoff, soil erosion,\nand nutrient loss were highest for the fallow plots; values for these\nvariables for spring corn and winter wheat plots were not significantly\ndifferent. Crop rotation generated greater runoff, soil erosion, and\nnutrient loss compared to non-rotation. Soil erosion and associated\nnutrient loss increased, but not significantly, with slope for gradients\nof 0.5 degrees, 1 degrees, and 3 degrees, while runoff and associated\nnutrient loss did not increase. In addition, soil erosion and associated\nnutrient loss were significantly greater for slope lengths of 20 m vs.\n50 m. A structural equation model showed rainfall characteristics\nsignificantly impacted runoff and soil erosion and subsequently affected\nnutrient loss. This study increases the understanding of runoff, soil\nerosion, and nutrient loss from cropland with gentle slopes on the CLP.'],
#  ['Estimating the Methane Potential of Energy Crops: An Overview on Types\nof Data Sources and Their Limitations',
#   'As the anaerobic digestion of energy crops and crop residues becomes\nmore widely applied for bioenergy production, planners and operators of\nbiogas plants, and farmers who consider growing such crops, have a need\nfor information on potential biogas and methane yields. A rich body of\nliterature reports methane yields for a variety of such materials. These\ndata have been obtained with different testing methods. This work\nelaborates an overview on the types of data source available and the\nmethods that are commonly applied to determine the methane yield of an\nagricultural biomass, with a focus on European crops. Limitations\nregarding the transferability and generalisation of data are explored,\nand crop methane values presented across the literature are compared.\nLarge variations were found for reported values, which can only\npartially be explained by the methods applied. Most notably, the\nintra-crop variation of methane yield (reported values for a single crop\ntype) was higher than the inter-crop variation (variation between\ndifferent crops). The pronounced differences in reported methane yields\nindicate that relying on results from individual assays of candidate\nmaterials is a high-risk approach for planning biogas operations, and\nthe ranges of values such as those presented here are essential to\nprovide a robust basis for estimation.'],
#  ['Classification and Digital Mapping of Soils in a Semiarid Region of\nAfghanistan',
#   'A soil map provides information on soil spatial distribution. Such\ninformation is essential for effective use of soil resources for crop\nproduction, land evaluation, spatial planning, environmental control,\nand for other similar purposes. In this study, a digital soil map for a\nsemiarid region of Afghanistan was developed. This map contains soil\ntaxonomic information up to the subgroup level, which is the first such\nattempt in Afghanistan. A total of 114 soil samples were collected in\nand around the Khost Province through an intensive soil survey. The\ncollected samples were classified into 14 subgroups of soils, following\nthe USDA soil classification system. A soil land inference model (SoLIM)\nwas applied for mapping the recognized 14 soil subgroups digitally, via\nan expert knowledge-based fuzzy soil inference scheme, with surface\ntopography and other spatial data as inputs. The overall accuracies from\nthe error matrix and Kappa statistics were 0.74 and 0.71, respectively.\nThis map was also compared with the currently used soil map. A general\nagreement between the two maps was found in the spatial distribution of\nsoil classes, at the great group level. However, the newly developed map\ncontains more detailed information on soils, which might be useful for\nthe advanced use of soil information, for example, to better determine\nthe crop type for cultivation by considering the detailed soil\nproperties. Throughout this study, 14 different recognized classes of\nsoil subgroups were digitally mapped in the study area.'],
#  ["Climate change may interact with nitrogen fertilizer management leading\nto different ammonia loss in China's croplands",
#   "Despite research into the response of ammonia (NH3) volatilization in\nfarmland to various meteorological factors, the potential impact of\nfuture climate change on NH3 volatilization is not fully understood.\nBased on a database consisting of 1063 observations across China,\nnonlinear NH3 models considering crop type, meteorological, soil and\nmanagement variables were established via four machine learning methods,\nincluding support vector machine, multi-layer perceptron, gradient\nboosting machine and random forest (RF). The RF model had the highest\nR-2 of 0.76 and the lowest RMSE of 0.82 kg NH3-N ha(-)(1), showing the\nbest simulation capability. Results of model importance indicated that\nNH3 volatilization was mainly controlled by total input of N fertilizer,\nfollowed by meteorological factors, human managements and soil\ncharacteristics. The NH3 emissions of China's cereal production (paddy\nrice, wheat and maize) in 2018 was estimated to be 3.3 Mt NH3-N. By\n2050, NH3 volatilization will increase by 23.1-32.0\\% under different\nclimate change scenarios (Representative Concentration Pathways, RCPs),\nand climate change will have the greatest impact on NH3 volatilization\nin the Yangtze river agro-region of China due to high warming effects.\nHowever, the potential increase in NH3 volatilization under future\nclimate change can be mitigated by 26.1-47.5\\% through various N\nfertilizer management optimization options."],
#  ['Estimation of crop water stress index and leaf area index based on\nremote sensing data',
#   "Estimation of crop water stress index (CWSI) and leaf area index (LAI)\nover large-irrigation schemes requires the use of cutting-edge\ntechnologies. Combinations of remote sensing techniques with\nground-truth data have become available for use at the catchment level.\nThese approaches allow us to estimate actual evapotranspiration and have\nthe capability of monitoring crop water status and saving irrigation\nwater in water-scarce regions. This study was conducted in the Eastern\nMediterranean Region of Turkiye. Fully distributed CWSI maps were\ngenerated and we assessed the relationship between CWSI and the LAI for\nsome specific crops in the winter season of 2021. Landsat 7 and 8 data\nwere used and meteorological data were acquired from two stations in the\nstudy area. ``Mapping Evapotranspiration at high Resolution with\nInternalized Calibration' methodology was applied to estimate the energy\nbalance components. CWSI maps displayed spatio-temporal changes in\ntandem with crop-type variations. Consequently, results presented a high\ncorrelation (r 1/4 0.95 and r 1/4 0.99 for wheat and lettuce,\nrespectively) between CWSI and LAI, a moderate correlation (r 1/4 0.44)\nfor potatoes in the winter season. Thus, by utilizing remotely sensed\ndata, the CWSI values would be directly estimated without requiring any\nin situ measurements of the canopy and air temperature over-irrigation\nscheme."],
#  ['The nutritional quality of cereals varies geospatially in Ethiopia and\nMalawi',
#   'Micronutrient deficiencies (MNDs) remain widespread among people in\nsub-Saharan Africa(1-5), where access to sufficient food from plant and\nanimal sources that is rich in micronutrients (vitamins and minerals) is\nlimited due to socioeconomic and geographical reasons(4-6). Here we\nreport the micronutrient composition (calcium, iron, selenium and zinc)\nof staple cereal grains for most of the cereal production areas in\nEthiopia and Malawi. We show that there is geospatial variation in the\ncomposition of micronutrients that is nutritionally important at\nsubnational scales. Soil and environmental covariates of grain\nmicronutrient concentrations included soil pH, soil organic matter,\ntemperature, rainfall and topography, which were specific to\nmicronutrient and crop type. For rural households consuming locally\nsourced food-including many smallholder farming communities-the location\nof residence can be the largest influencing factor in determining the\ndietary intake of micronutrients from cereals. Positive relationships\nbetween the concentration of selenium in grain and biomarkers of\nselenium dietary status occur in both countries. Surveillance of MNDs on\nthe basis of biomarkers of status and dietary intakes from national- and\nregional-scale food-composition data(1-7) could be improved using\nsubnational data on the composition of grain micronutrients. Beyond\ndietary diversification, interventions to alleviate MNDs, such as food\nfortification(8,9) and biofortification to increase the micronutrient\nconcentrations in crops(10,11), should account for geographical effects\nthat can be larger in magnitude than intervention outcomes.'],
#  ['Agricultural land suitability classification and crop suggestion using\nmachine learning and spatial multicriteria decision analysis in\nsemi-arid ecosystem',
#   'Agricultural land evaluation for crop cultivation plays a vital role in\ndeveloping a sustainable and productive agricultural system. The\ntraditional way of manual land evaluation is time-consuming, costlier,\nrequires expert knowledge, and prone to human errors. The application of\nmachine learning is making its impact on almost every field. To overcome\nthe challenges of manual land evaluation automated approach of machine\nlearning can play an influential role in agriculture. Therefore, the\npresent study aimed to investigate and propose an automated solution for\nagricultural land suitability evaluation for two major crops, i.e.,\nwheat and mustered, based on a hybrid approach of multicriteria decision\nanalysis (MCDA) and machine learning (ML). The proposed framework is\nbased on the land suitability assessment framework proposed by the Food\nand Agriculture Organization (FAO). For evaluating suitability levels of\nland units, three major influential categories of geospatial parameters\nare considered, i.e., soil, climatic, and topographic. The MCDA\ntechnique of analytical hierarchy process (AHP) has been used to analyze\ncrop suitability utilizing these geospatial parameters. The ML models\nare constructed to map the quantified crop suitability results and\nsuggest the most suitable crop to be cultivated. The obtained results\nindicate that the Balanced Bagging classifier achieved the highest\nbalanced accuracies of 97.69\\% and 97.57\\% for mustered and wheat crop\nsuitability predictions, respectively, and a balanced accuracy of\n97.36\\% for crop classification. Since the AHP method is a systematic\napproach to decision analysis, while ML is a data-driven approach, the\nproposed unified approach offers more comprehensive predictions. The\npotential of the proposed framework is evaluated for the Abhanpur\ndistrict of Chhattisgarh state, India. The proposed ML-based approach\novercomes the limitations of the conventional methods and provides\nprecise decisions; therefore, could turn the attention to ML in future\ncropland suitability evaluation studies.'],
#  ['A study on the use of UAV images to improve the separation accuracy of\nagricultural land areas',
#   'Classifying satellite images with medium spatial resolution such as\nLandsat, it is usually difficult to distinguish between plant species,\nand it is impossible to determine the area covered with weeds. In this\nstudy, a Landsat 8 image along with UAV images utilized to separate\npistachio cultivars and separate weed from trees. To use the high\nspatial resolution of UAV images, image fusion was carried out through\nthe high-pass filter, wavelet, principal component transformation,\nBROVEY, IHS, and Gram Schmidt methods. ERGAS, RMSE, and correlation\ncriteria were applied to assess their accuracy. The results represented\nthat the wavelet method with R2, RMSE, and ERGAS 0.91, 12.22 cm, and\n2.05 respectively had the highest accuracy in combining these images.\nThen, images obtained by this method were chosen with a spatial\nresolution of 20 cm for classification. Different classification methods\nincluding unsupervised method, maximum likelihood, minimum distance,\nfuzzy artmap, perceptron, and tree methods were evaluated. Moreover, six\nsoil classes, Ahmad Aghaei, Akbari, Kalleh Ghoochi, Fandoghi, and a\nmixing class of Kalleh Ghoochi and Fandoghi were applied, and also three\nclasses of soil, pistachio tree and weeds were extracted from the trees.\nThe results demonstrated that the fuzzy artmap method had the highest\naccuracy in separating weeds from trees, differentiating various\npistachio cultivars with Landsat image and also classification with\ncombined image and had 0.87, 0.79, and 0.87 kappa coefficients\nrespectively. The comparison between pistachio cultivars through Landsat\nimage and the combined image showed that the validation accuracy\nobtained from harvest has raised by 17\\% because of the combination of\nimages. The results of this study indicated that the combination of UAV\nand Landsat 8 images affects well to separate pistachio cultivars and\ndetermine the area covered with weeds.'],
#  ['Root-Lesion Nematodes Affecting Dryland Cereals in the Semiarid Pacific\nNorthwest USA',
#   "Root-lesion nematodes (Pratylenchus spp.) are parasites that invade and\ndeteriorate roots, thereby reducing the efficiency of water and nutrient\nuptake. Pratylenchus neglectus and P. thornei are the two species that\nare most prevalent and cause reduced yields of rainfed wheat and barley\nin semiarid regions of the Pacific Northwest. They are particularly\ndamaging where wheat and barley are produced without irrigation in areas\nreceiving less than 450 mm (18 in.) of precipitation annually. This\nreview is focused on the biology and management of P. neglectus and P.\nthornei in semiarid rainfed agriculture. Characteristics of climates,\nsoils, and crop production systems are described as a preface to\nconstraints placed upon management options. Discussions include the\neconomic importance, host ranges, and protocols for sampling and species\nidentification. Discussion of disease management options include crop\nrotation, genetic resistance and tolerance, planting date, trap and\nbiofumigant crops, crop nutrition, chemical and biological nematicides,\nand tillage. Predictions for rainfed agriculture in a period of changing\nclimate are presented, as are suggestions for important areas of\nresearch including crop genetics, nematode testing, and communication of\nresults, Pratylenchus biology, mechanisms of resistance, the phytobiome,\nand closing the ``yield gap{''} between actual and attainable yields."],
#  ['Data Value Extraction Mechanism in a Resilient Fog-based IoT System for\nSmart Irrigation',
#   'An IoT system of water management for automated irrigation in\nagriculture can use sensors to obtain metrics such as soil moisture,\nsoil temperature, soil pH, air humidity, and air temperature to make\nmore precise decisions in irrigation. Fog computing can store and\nanalyze data during cloud disconnection and providing system\navailability due to Internet disconnections, expected in a farm\nscenario. However, fog nodes have resource constraints. Also, depending\non the crop type or crop growth stage, not all collected data are\nrelevant for irrigation. In some cases, the IoT system uses multi-depth\nsensors to collect data. Still, depending on the plant root size, some\ndeeper measurements collect irrelevant data and increase the demand for\nmemory in IoT devices. This paper evaluates a data value mechanism to\nextract relevant data in a fog-based IoT system for smart irrigation. We\nconsider the system with a workload of 500 data packets per minute\nduring cloud network availability and unavailability. We create\nsynthetic input data using three soil moistures for different depths and\npermute data value configurations to consider one, two, or three depths\nvalues as relevant data in the experiment. Our results show a data size\nreduction of 23.15\\% or 47.60\\%, depending on the crop growth stage. We\nalso perceive a statistical tie for packet delay and batch transfer time\nmetrics with all configurations.'],
#  ['Multiscale Superpixel-Based Fine Classification of Crops in the\nUAV-Manned Hyperspectral Imagery',
#   'As an effective approach to obtaining agricultural information, the\nremote sensing technique has been applied in the classification of crop\ntypes. The unmanned aerial vehicle (UAV)-manned hyperspectral sensors\nprovide imagery with high spatial and high spectral resolutions.\nMoreover, the detailed spatial information, as well as abundant spectral\nproperties of UAV-manned hyperspectral imagery, opens a new avenue to\nthe fine classification of crops. In this manuscript, multiscale\nsuperpixel-based approaches are proposed for the fine identification of\ncrops in the UAV-manned hyperspectral imagery. Specifically, the\nmultiscale superpixel segmentation is performed and a series of\nsuperpixel maps can be obtained. Then, the multiscale information is\nintegrated into image classification by two strategies, namely\npre-processing and post-processing. For the pre-processing strategy, the\nsuperpixel is regarded as the minimum unit for image classification,\nwhose feature is obtained by using the average of spectral values of\npixels within it. At each scale, the classification is performed on the\nbasis of the superpixel. Then, the multiscale classification results are\ncombined to generate the final map. For the post-processing strategy,\nthe pixel-wise classification is implemented to obtain the label and\nposterior probabilities of each pixel. Subsequently, the\nsuperpixel-based voting is conducted at each scale, and these obtained\nvoting results are fused to generate the multiscale voting result. To\nevaluate the effectiveness of the proposed approaches, three\nopen-sourced hyperspectral UAV-manned datasets are employed in the\nexperiments. Meanwhile, seven training sets with different numbers of\nlabeled samples and two classifiers are taken into account for further\nanalysis. The results demonstrate that the multiscale superpixel-based\napproaches outperform the single-scale approaches. Meanwhile, the\npost-processing strategy is superior to the pre-processing strategy in\nterms of higher classification accuracies in all the datasets.'],
#  ['Identification of Abandoned Jujube Fields Using Multi-Temporal\nHigh-Resolution Imagery and Machine Learning',
#   'The jujube industry plays a very important role in the agricultural\nindustrial structure of Xinjiang, China. In recent years, the\nabandonment of jujube fields has gradually emerged. It is critical to\ninventory the abandoned land soon after it is generated to adjust\nagricultural production better and prevent the negative impacts from the\nabandonment (such as outbreaks of diseases, insect pests, and fires).\nHigh-resolution multi-temporal satellite remote sensing images can be\nused to identify subtle differences among crops and provide a good tool\nfor solving this problem. In this research, both field-based and\npixel-based classification approaches using field boundaries were used\nto estimate the percentage of abandoned jujube fields with\nmulti-temporal high spatial resolution satellite images (Gaofen-1 and\nGaofen-6) and the Random Forest algorithm. The results showed that both\napproaches produced good classification results and similar\ndistributions of abandoned fields. The overall accuracy was 91.1\\% for\nthe field-based classification and 90.0\\% for the pixel-based\nclassification, and the Kappa was 0.866 and 0.848 for the respective\nclassifications. The areas of abandoned land detected in the field-based\nand pixel-based classification maps were 806.09 ha and 828.21 ha,\nrespectively, accounting for 8.97\\% and 9.11\\% of the study area. In\naddition, feature importance evaluations of the two approaches showed\nthat the overall importance of texture features was higher than that of\nvegetation indices and that 31 October and 10 November were important\ndates for abandoned land detection. The methodology proposed in this\nstudy will be useful for identifying abandoned jujube fields and have\nthe potential for large-scale application.'],
#  ['Research hotspots and frontiers in agricultural multispectral\ntechnology: Bibliometrics and scientometrics analysis of the Web of\nScience',
#   'Multispectral technology has a wide range of applications in\nagriculture. By obtaining spectral information during crop production,\nkey information such as growth, pests and diseases, fertilizer and\npesticide application can be determined quickly, accurately and\nefficiently. The scientific analysis based on Web of Science aims to\nunderstand the research hotspots and areas of interest in the field of\nagricultural multispectral technology. The publications related to\nagricultural multispectral research in agriculture between 2002 and 2021\nwere selected as the research objects. The softwares of CiteSpace,\nVOSviewer, and Microsoft Excel were used to provide a comprehensive\nreview of agricultural multispectral research in terms of research\nareas, institutions, influential journals, and core authors. Results of\nthe analysis show that the number of publications increased each year,\nwith the largest increase in 2019. Remote sensing, imaging technology,\nenvironmental science, and ecology are the most popular research\ndirections. The journal Remote Sensing is one of the most popular\npublishers, showing a high publishing potential in multispectral\nresearch in agriculture. The institution with the most research\nliterature and citations is the USDA. In terms of the number of papers,\nMtanga is the author with the most published articles in recent years.\nThrough keyword co-citation analysis, it is determined that the main\nresearch areas of this topic focus on remote sensing, crop\nclassification, plant phenotypes and other research areas. The\nliterature co-citation analysis indicates that the main research\ndirections concentrate in vegetation index, satellite remote sensing\napplications and machine learning modeling. There is still a lot of room\nfor development of multi-spectrum technology. Further development can be\ncarried out in the areas of multi-device synergy, spectral fusion,\nairborne equipment improvement, and real-time image processing\ntechnology, which will cooperate with each other to further play the\nrole of multi-spectrum in agriculture and promote the development of\nagriculture.'],
#  ['Irrigation Detection Using Sentinel-1 and Sentinel-2 Time Series on\nFruit Tree Orchards',
#   "In arid and semi-arid regions, irrigation is crucial to mitigate water\nstress and yield loss. However, the overexploitation of water resources\nby the agricultural sector together with the climate change effects can\nlead to water scarcity. Effective regional water management depends on\nestimating irrigation demand using maps of irrigable areas or national\nand regional statistics of irrigated areas. These statistical data are\nnot always of reliable quality because they generally do not reflect the\nupdated spatial distribution of irrigated and rainfed fields. In this\ncontext, remote sensing provides reliable methods for gathering useful\nagricultural information from derived records. The combined use of\noptical and radar Earth Observation data enhances the probability of\ndetecting irrigation events, which can improve the accuracy of\nirrigation mapping. Hence, we aimed to utilize Sentinel-1 (VV and VH)\nand Sentinel-2 (NDVI) data to classify irrigated fruit trees and rainfed\nones in a study area located in the Castilla La-Mancha region in Spain.\nTo obtain these time-series data from Sentinel-1 and Sentinel-2, which\nconstitute the input data for the classification algorithms, a tool has\nbeen developed for automating the download from the Sentinel Hub. This\ntool downloads products organized by tiles for the region of interest\nand for the entire required time-series, ensuring the spatial\nrepeatability of each pixel across all products and dates. The\nclassification of irrigated plots was carried out by SVM Support Vector\nMachine. The employed methodology displayed promising results, with an\noverall accuracy of 88.4\\%, indicating the methodology's ability to\ndetect irrigation over orchards that were declared as non-irrigated.\nThese results were evaluated by applying the change detection method of\nthe sigma p0 backscattering coefficient at plot scale."],
#  ['Methodology for groundnut discrimination based on timeseries of\ndual-polarimetric SAR parameters',
#   'The groundnut, also known as peanut, is a legume crop that is classified\nas both a grain legume and an oil crop (due to its high oil content).\nAbout 85\\% of the total groundnut in India is sown in the kharif season\nunder rainfed conditions. This makes it extremely difficult to apply the\noptical remote sensing methodologies for groundnut discrimination and\nacreage estimation. We develop a remote sensing strategy based on\ntimeseries synthetic aperture radar (SAR) imagery, which is immune to\nthe rainy conditions of the observation period. Further, our work is\ndistinct from the traditional multitemporal SAR backscatter analysis as\nit incorporates polarimetric parameters such as the alpha angle (a) and\nthe polarimetric radar vegetation index to aid discrimination. These\nparameters were shortlisted on the basis of maximal sensitivity to\ngroundnut growth stages. Random forest classifier, an ensemble\nlearning-based classifier, is used to carryout the crop classification\nusing these parameters. This approach is contrasted with SAR\nbackscatter-based analysis (using the same RF classifier) and with a\nEuclidean distance (ED)-based model matching method (with the same\npolarimetric parameters). A detailed comparative analysis of\nclassification accuracy of groundnut discrimination is carried out using\nextensive ground truth data over the agricultural fields of Junagadh\ndistrict in the Gujarat state of Western India. The backscatter-based\nanalysis with RF achieves 86.2\\% overall accuracy in discriminating\ngroundnut (with the competing cotton crop), whereas polarimetric\nparameters with ED model matching achieves 76\\%. Using the proposed\nmethod, with dual-pol parameters derived out of Sentinel-1 SAR data, we\nreport 92.7\\% overall accuracy with a kappa coefficient of 0.81. The\nmajor insight is that combining timeseries polarimetric information\ntogether with a good machine learning classifier improves the\nclassification accuracy of short crops compared to nonpolarimetric\napproach. (C) 2022 Society of Photo-Optical Instrumentation Engineers\n(SPIE)'],
#  ['Assessment of Cropland Changes Due to New Canals in Vientiane Prefecture\nof Laos using Earth Observation Data',
#   'The lower catchment area of a Mak Hiao river system is vulnerable to\nflash floods and water stress. So it is important to construct\nirrigation structures in this area to minimize floods during the rainy\nseason and store water for the winter season. The Asian Development Bank\n(ADB) has been supporting the Government of Laos in constructing such\nsmall reservoirs like Donkhuay schemes 1 \\& 2, Mak Hiao, Nalong 3 and\nSang Houabor projects in lower catchment areas. Our study evaluated the\nimpacts of small irrigation schemes in terms of land-use/landcover\n(LULC), crop intensity, and productivity changes, using high resolution\nsatellite imagery, socioeconomic, and ground data. We analyzed the\ntemporal cropping pattern in the Vientiane prefecture of Laos using\nPlanet and Sentinel-2 data. On the other hand, crop intensity and\ncropland changes were mapped using Sentinel-2 data and spectral matching\ntechniques (SMTs). The crop classification accuracy based on field-plot\ndata was 88.6\\%. Our results show that irrigation projects in the lower\ncatchment areas brought about significant on-site changes in terms of\ncropland expansion and increased crop intensity. Remarkable changes in\nLULC were observed especially in the command areas owing to an increase\nof about 300\\% in crop area with access to irrigation and increase of\nwater bodies by 31\\%. Our study found that interventions at the level of\nthe command area do improved on-site soil, water and environmental\nservices. They study emphasized underline the role of land-use\nregulations in reducing pressure on natural land-use systems and thereby\nserving the major goal of up-scaling sustainable natural resource\nmanagement. The study documented the vital role of small/medium\nirrigation projects in restoring ecosystem services such as cropping\npatterns and LULC conversion.'],
#  ['Comparing Machine and Deep Learning Methods for the Phenology-Based\nClassification of Land Cover Types in the Amazon Biome Using Sentinel-1\nTime Series',
#   'The state of Amapa within the Amazon biome has a high complexity of\necosystems formed by forests, savannas, seasonally flooded vegetation,\nmangroves, and different land uses. The present research aimed to map\nthe vegetation from the phenological behavior of the Sentinel-1 time\nseries, which has the advantage of not having atmospheric interference\nand cloud cover. Furthermore, the study compared three different sets of\nimages (vertical-vertical co-polarization (VV) only, vertical-horizontal\ncross-polarization (VH) only, and both VV and VH) and different\nclassifiers based on deep learning (long short-term memory (LSTM),\nBidirectional LSTM (Bi-LSTM), Gated Recurrent Units (GRU), Bidirectional\nGRU (Bi-GRU)) and machine learning (Random Forest, Extreme Gradient\nBoosting (XGBoost), k-Nearest Neighbors, Support Vector Machines (SVMs),\nand Multilayer Perceptron). The time series englobed four years\n(2017-2020) with a 12-day revisit, totaling 122 images for each VV and\nVH polarization. The methodology presented the following steps: image\npre-processing, temporal filtering using the Savitsky-Golay smoothing\nmethod, collection of samples considering 17 classes, classification\nusing different methods and polarization datasets, and accuracy\nanalysis. The combinations of the VV and VH pooled dataset with the\nBidirectional Recurrent Neuron Networks methods led to the greatest F1\nscores, Bi-GRU (93.53) and Bi-LSTM (93.29), followed by the other deep\nlearning methods, GRU (93.30) and LSTM (93.15). Among machine learning,\nthe two methods with the highest F1-score values were SVM (92.18) and\nXGBoost (91.98). Therefore, phenological variations based on long\nSynthetic Aperture Radar (SAR) time series allow the detailed\nrepresentation of land cover/land use and water dynamics.'],
#  ['Transformer Neural Network for Weed and Crop Classification of High\nResolution UAV Images',
#   'Monitoring crops and weeds is a major challenge in agriculture and food\nproduction today. Weeds compete directly with crops for moisture,\nnutrients, and sunlight. They therefore have a significant negative\nimpact on crop yield if not sufficiently controlled. Weed detection and\nmapping is an essential step in weed control. Many existing research\nstudies recognize the importance of remote sensing systems and machine\nlearning algorithms in weed management. Deep learning approaches have\nshown good performance in many agriculture-related remote sensing tasks,\nsuch as plant classification, disease detection, etc. However, despite\nthe success of these approaches, they still face many challenges such as\nhigh computation cost, the need of large labelled datasets, intra-class\ndiscrimination (in growing phase weeds and crops share many attributes\nsimilarity as color, texture, and shape), etc. This paper aims to show\nthat the attention-based deep network is a promising approach to address\nthe forementioned problems, in the context of weeds and crops\nrecognition with drone system. The specific objective of this study was\nto investigate visual transformers (ViT) and apply them to plant\nclassification in Unmanned Aerial Vehicles (UAV) images. Data were\ncollected using a high-resolution camera mounted on a UAV, which was\ndeployed in beet, parsley and spinach fields. The acquired data were\naugmented to build larger dataset, since ViT requires large sample sets\nfor better performance, we also adopted the transfer learning strategy.\nExperiments were set out to assess the effect of training and validation\ndataset size, as well as the effect of increasing the test set while\nreducing the training set. The results show that with a small labeled\ntraining dataset, the ViT models outperform state-of-the-art models such\nas EfficientNet and ResNet. The results of this study are promising and\nshow the potential of ViT to be applied to a wide range of remote\nsensing image analysis tasks.'],
#  ['Research on remote sensing classification of fruit trees based on\nSentinel-2 multi-temporal imageries',
#   'Accurately obtaining the spatial distribution information of fruit tree\nplanting is of great significance to the development of fruit tree\ngrowth monitoring, disease and pest control, and yield estimation. In\nthis study, the Sentenel-2 multispectral remote sensing imageries of\ndifferent months during the growth period of the fruit trees were used\nas the data source, and single month vegetation indices, accumulated\nmonthly vegetation indices ( n-ary sumation VIs), and difference\nvegetation indices between adjacent months ( increment VIs) were\nconstructed as input variables. Four conventional vegetation indices of\nNDVI, PSRI, GNDVI, and RVI and four improved vegetation indices of\nNDVIre1, NDVIre2, NDVIre3, and NDVIre4 based on the red-edge band were\nselected to construct a decision tree classification model combined with\nmachine learning technology. Through the analysis of vegetation indices\nunder different treatments and different months, combined with the\nattribute of Feature\\_importances\\_, the vegetation indices of different\nperiods with high contribution were selected as input features, and the\nMax\\_depth values of the decision tree model were determined by the\nhyperparameter learning curve. The results have shown that when the\nMax\\_depth value of the decision tree model of the vegetation indices\nunder the three treatments was 6, 8, and 8, the model classification was\nthe best. The accuracy of the three vegetation index processing models\non the training set were 0.8936, 0.9153, and 0.8887, and the accuracy on\nthe test set were 0.8355, 0.7611, and 0.7940, respectively. This method\ncould be applied to remote sensing classification of fruit trees in a\nlarge area, and could provide effective technical means for monitoring\nfruit tree planting areas with medium and high resolution remote sensing\nimageries.'],
#  ['Assessment of Irrigation Demands Based on Soil Moisture Deficits Using a\nSatellite-Based Hydrological Model',
# ...
#  ['Can crop yields be secured while reducing phosphorus accumulation in\nsoil? Assessing decades of contrasting fertilizer strategies.',
#   'Context: A balanced phosphorus (P) use in agriculture, where P\nfertilizer input matches crop offtake, is necessary to avoid\naccumulation of P in soil that is a chronic source for diffuse P loss.\nMoreover, mineral P fertilizers produced from rock phosphate is a\nlimited resource, and identification of alternative P fertilizer sources\nsuch as animal manures that secure yields without P surpluses is\ntherefore essential for sustainable P use.Objective: The objective was\nto explore crop productivity and soil P accumulation after long-term\ninput of different P fertilizer sources. Moreover, Olsen-P contents in\nsoil were determined to evaluate if crop yields and P balances were\nreflected in measures of available P. Methods: On a coarse sandy soil\ninstalled in lysimeters under field conditions, crop yields and P\nsurpluses from 1992 to 2022 were quantified as affected by P fertilizer\nsource (annual additions of solid pig manure, pig slurry and mineral\nfertilizer) since 1975. All lysimeters received mineral nitrogen (N)\nfertilizers according to the crop demand. Olsen-P contents in the upper\nsoil layer (0-25 cm) were measured over three decades, and vertical\ndistribution of P in soil down to 140 cm depth was studied at the end of\nthe experimental period.Results: For oats, barley, pea and beet root,\nlong-term fertilization with solid pig manure at a rate of 15 kg P\nha(-1) year(-1) resulted in similar yields as after fertilization with\n30 kg mineral P ha(-1) year(-1). After 30 years, the build-up of P in\nsoil was much lower after solid pig manure inputs (accumulation of 8 kg\nP ha(-1)) than after mineral P fertilization (accumulation of 51 and 434\nkg P ha(-1) in soil receiving 15 and 30 kg mineral P ha(-1) year(-1),\nrespectively). The long-term fertilizer treatments affected Olsen-P\nlevels in the upper soil layer with highest Olsen-P contents (>40 mg P\nkg(-1)) after fertilization with 30 kg mineral P ha(-1) year-1. Only\nmaize benefitted from high Olsen-P levels and generous input of mineral\nP, whereas the yield potential for the other crop types could be reached\nat low to moderate Olsen-P levels after long-term additions of solid pig\nmanure. More P was found in the deep soil layers (65-140 cm) after\naddition of pig slurry than solid pig manure. Conclusions: The results\nshowed that solid pig manure was a valuable P source that had the\npotential to replace mineral P fertilizers without compromising crop\nproductivity, while ensuring low P surpluses. Implications: This study\nsuggests that the Olsen-P test could not stand alone in predicting P\nrequirement but should preferably be supplemented with knowledge on\nfertilizer source, crop type and P offtakes to ensure a more balanced\nfertilizer P use.'],
#  ['Geo-CropSim: A Geo-spatial crop simulation modeling framework for\nregional scale crop yield and water use assessment',
#   'Remote sensing derived datasets (e.g. Leaf Area Index (LAO) are\nincreasingly being used in process based cropping system models to\nimprove the prediction skill of the simulations when implementing\noperationally at regional scale. However, challenges such as inadequate\nquality of the available remote sensing data products and high reliance\nof models on climate variables and their uncertainties still exist. To\naddress these challenges, we developed Geo-CropSim, a spatial modeling\nframework to use high quality remote sensing products in the\nEnvironmental Policy Integrated Climate (EPIC) agroecosystem model to\nregulate simulated processes and improve predictions of crop yield and\nevapotranspiration. Geo-CropSim comprises three main features 1) pixel\nlevel model initialization using crop emergence dates; 2) ability of the\nEPIC model to read in the PROSAIL (i.e. combined PROSPECT leaf optical\nproperties model and SAIL canopy bidirectional reflectance model)\ninversion-based crop type LAI; and 3) a stress adjustment function to\nregulate simulated stress using LAI anomalies. To understand its\nperformance, we implemented it over the State of Nebraska to estimate\ncorn (Zea mays L.) and soybean (Glycine max {[}Merr.]) yields and\nevapotranspiration (ET) for 2012 (drought year) and 2015 (normal year)\nat 500-m resolution. Results showed that emergence dates and seasonal\nLAI captured spatial and temporal differences in crop progression (e.g.\ndelayed planting in 2015) and growth (e.g. declined LAI in 2012) driven\nby regional differences in crop management and weather conditions very\nwell. These differences were reflected in Geo-CropSim yield estimates,\nand showed improved spatial and temporal details compared over those\nfrom EPIC simulations obtained without using remote sensing derived\nemergence and LAI. Results revealed that Mean Absolute Percentage Error\n(MAPE) and Root Mean Square Error (RMSE) of Geo-CropSim yield estimates,\ncomputed based on USDA-NASS reported yields, were 18.85\\% and 1.22 Mg\nha(-1) for corn, and 17.90\\% and 0.46 Mg ha(-1) for soybeans,\nrespectively, which are substantially lower than those of original EPIC\nestimates (MAPE = 33.74\\% and RMSE = 2.18 Mg ha(-1) for corn; and MAPE =\n40.71\\% and RMSE = 0.98 Mg ha(-1) for soybeans). Further, Geo-CropSim\nwas able to capture ET and transpiration dynamics reasonably well (e.g.\n10-12 \\% lower values for soybeans compared to corn values), and showed\ngood agreement with flux measurements (i.e. R-2 values of 0.63 and 0.72,\nRMSE values of 29.88 and 33.41 mm, and MAPE values of 5.0\\% and 6.8\\%\nfor corn and soybean, respectively). Overall, this study demonstrated\nthat Geo-CropSim has considerable potential to serve as a reliable\noperational tool to assess crop yields and water use under various\ncropping systems and to help in regional yield monitoring and water\nresource management.'],
#  ['Hymenopteran Parasitoids of Aphid Pests within Australian Grain\nProduction Landscapes',
#   "Simple Summary\nIn grain crops, aphids are important pests, but they can be suppressed\nby parasitoid wasps that use them as hosts for their developing\noffspring. These wasps occur naturally in the environment and can be\nutilized in the control of these pests. We investigated how the number\nand species of pest aphids within the grain crops varied over the\nseason, how their associated parasitoid wasp species and numbers varied\nover time, and how these organisms interacted at crop edges. In our\nstudy, aphid numbers remained low early in the season, and increased as\nthe crop growth progressed. Wheat field edges can act as reservoirs for\nthe aphids and wasps; however, this was not the case for canola field\nedges, likely due to the different plant hosts available. One wasp\ndominated this study throughout the canola fields, although it was only\nfound in low numbers at field edges and in wheat fields. Within these\nareas, another wasp dominated. These findings can assist in the\nmanagement of grain aphid pests.\nIn grain crops, aphids are important pests, but they can be suppressed\nby hymenopteran parasitoids. A challenge in incorporating parasitoids\ninto Integrated Pest Management (IPM) programs, however, is that\nparasitoid numbers can be low during periods within the season when\naphids are most damaging. Understanding the population dynamics of key\naphid species and their parasitoids is central to ameliorating this\nproblem. To examine the composition and seasonal trends of both aphid\nand parasitoid populations in south-eastern Australia, samples were\ntaken throughout the winter growing seasons of 2017 and 2018 in 28\nfields of wheat and canola. Myzus persicae (Sulzer) was the most\nabundant aphid species, particularly within canola crops. Across all\nfields, aphid populations remained relatively low during the early\nstages of crop growth and increased as the season progressed. Seasonal\npatterns were consistent across sites, due to climate, crop growth\nstage, and interactions between these factors. For canola, field edges\ndid not appear to act as reservoirs for either aphids or parasitoids, as\nthere was little overlap in the community composition of either, but for\nwheat there was much similarity. This is likely due to the presence of\nsimilar host plants within field edges and the neighbouring crop,\nenabling the same aphid species to persist within both areas.\nDiaeretiella rapae (M'Intosh) was the most common parasitoid across our\nstudy, particularly in canola, yet was present only in low abundance at\nfield edges. The most common parasitoid in wheat fields was Aphidius\nmatricariae (Haliday), with field edges likely acting as a reservoir for\nthis species. Secondary parasitoid numbers were consistently low across\nour study. Differences in parasitoid species composition are discussed\nin relation to crop type, inter-field variation, and aphid host. The\nresults highlight potential focal management areas and parasitoids that\ncould help control aphid pests within grain crops."],
#  ['Crop phenology reshapes the food-safety landscape for roe deer in an\nagroecosystem',
#   "Understanding the behavioural adjustments of wildlife in anthropized\nlandscapes is key for promoting sustainable human-wildlife coexistence.\nLittle is known, however, about how synanthropic species navigate\nspatio-temporal variation in the availability of food and cover that are\nshaped by human practices such as agriculture.Animal habitat use is\npredominantly driven by spatial and temporal variations in food and\ncover, as individuals respond to fluctuations in the trade-off between\nfood acquisition and risk avoidance. In agroecosystems, the availability\nof high-quality forage and cover is dependent on agricultural practices\n(e.g., harvesting) and crop phenology, providing an ideal opportunity to\nevaluate how wildlife adjust their behaviour in a heterogeneous\nhuman-dominated landscape.We investigated the influence of crop\nphenology on the behaviour of European roe deer (Capreolus capreolus) to\ninfer the functional roles of crop types in the food-cover landscape. We\nanalysed the habitat selection and activity patterns of 105 GPS-collared\nadult female roe deer using a unique data set combining field-specific\nland cover data, region-specific estimates of crop phenology and weekly\nharvesting data for three common crops in a French agroecosystem.We\nfound very distinct habitat selection and activity patterns according to\ncrop type, phenological stage and time of day. Wheat and artificial\nmeadows were strongly selected at night-time during the early and\npost-harvest stages only, when roe deer were highly active, suggestive\nof feeding activity. On the contrary, roe deer strongly selected maize\nduring the day when it was high enough to provide cover, when they were\nless active, indicating that it was primarily used for refuge. These\npatterns depended on the availability of more `natural' cover,\nsuggesting that mature maize may substitute for `natural' cover when the\nlatter is scarce.Synthesis and application: Our work highlights the\nimportance of behavioural plasticity and habitat complementation in the\npersistence of this synanthropic species in agroecosystems. This\nbehavioural adjustment may buffer the consequences of the reduction in\nnatural habitats that accompanies intensification of agricultural\nproduction and has implications for understanding how agricultural\npractices shape the food-safety trade-off of wildlife living in these\nhighly modified landscapes.\nPenser une coexistence durable entre humains et non-humains necessite\nune meilleure comprehension des ajustements comportementaux de la faune\nsauvage aux dynamiques des paysages anthropises. Peu d'etudes ont\nneanmoins considere comment la faune sauvage repond aux variations\nspatio-temporelles des ressources alimentaires et d'habitats refuge qui\nsont tributaires des pratiques humaines, comme\nl'agriculture.L'utilisation de l'espace par les animaux est\nprincipalement sous-tendue par les variations spatiales et temporelles\nen nourriture et en couvert, les individus repondant aux fluctuations du\ncompromis entre l'acquisition des ressources et l'evitement du risque.\nAu sein des agroecosystemes, la disponibilite en ressources alimentaires\nde haute qualite et en couvert vegetal depend de la phenologie des\ncultures agricoles et des pratiques agricoles (ex: la recolte), ce qui\nen font des systemes ideaux pour evaluer les ajustements comportementaux\nde la faune sauvage a des paysages heterogenes, faconnes par l'activite\nhumaine.Nous avons ainsi etudie l'influence de la phenologie des\ncultures agricoles sur le comportement du chevreuil d'Europe (Capreolus\ncapreolus) afin d'inferer les roles fonctionnels, en tant que ressource\net/ou couvert, pour chaque type de culture agricole. Nous avons analyse\nla selection d'habitat et les patrons d'activite de 105 chevreuils\nfemelles adultes, equipes de colliers GPS, dans un agroecosysteme\nfrancais. Pour ce faire, nous avons utilise un jeu de donnees unique\nassociant des donnees d'assolement a ...

# %%
list_from_df = df.values.tolist()

# %% [markdown]
# ###Initial Screening

# %%
from collections import Counter
import matplotlib.pyplot as plt
import random


# Function to analyze abstract
def analyze_relevant_paper(text):
    text = "text"
    prompt =  f"""#You are a research assistant. You are doing resrach on a topic named: Crop Classification using satellite images.
                  #Given a paper's title and Abstract  {text},
                  #you need to determine on the basis of title and abstract whether the paper is related to crop type mapping or crop type classification using satellite images.
                  #Return 'No' for papers that do not classify crops  using satellite imagery data.
                  #Return 'Yes' only for papers that strictly meet the criteria of classifying satellite imagery into crops.
                  #Provide your answer as 'Yes' or 'No'.
                  #Donot need to add anyother detail.
                  #Answer yes or no.""";
    try:
      keywords = model.generate_content(prompt)
      text = keywords.text
      print(text)
    except Exception as e:
      print(e)
    return text


# Analyze abstarct and find keywords
theme_keywords = []
identified_paper = []
i=0
for row,crow in zip(selected_columns,list_from_df):
    row = "".join(row)
    resp = analyze_relevant_paper(row)
    if(resp.lower() == "yes"):
      identified_paper.append(crow)
# Out:
# No
# Yes
# No
# Yes
# Yes
# No
# No
# No
# No
# No
# Yes
# No
# Yes
# No
# Yes
# No
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 784.78ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1164.84ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1043.19ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1063.32ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# Yes
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1012.69ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 962.29ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 987.83ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1139.58ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1062.94ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1341.76ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1319.76ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1417.69ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1316.12ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1518.84ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1316.44ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1316.08ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1366.89ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1316.81ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1316.56ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1296.01ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1525.85ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1418.18ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1338.42ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1304.83ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1442.36ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1341.10ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1493.27ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1038.28ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1065.03ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1042.68ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# Yes
# No
# No
# No
# No
# No
# No
# No
# Yes
# No
# No
# No
# Yes
# No
# Yes
# Yes
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 784.56ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# Yes
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1800.32ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1016.05ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1138.06ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1189.59ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1392.18ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1342.97ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1366.61ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1293.10ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1189.60ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1290.80ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1395.15ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1316.05ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1315.98ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1826.29ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1193.42ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1746.09ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1797.43ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1472.52ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1167.65ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1547.40ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1094.83ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1144.12ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# Yes
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1089.17ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1092.27ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# Yes
# Yes
# Yes
# Yes
# No
# No
# No
# Yes
# No
# Yes
# Yes
# No
# Yes
# Yes
# Yes
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 785.92ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# Yes
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 760.52ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1089.45ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1294.93ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1317.11ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1342.18ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1317.85ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1342.18ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1342.62ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1346.08ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1316.07ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1290.85ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1345.02ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1113.65ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1115.15ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1041.81ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1393.15ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1418.02ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1292.86ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1316.66ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1494.12ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1291.69ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1443.38ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1473.52ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1344.68ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1317.26ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# Yes
# Yes
# Yes
# Yes
# No
# No
# Yes
# No
# No
# No
# Yes
# No
# No
# No
# No
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 836.08ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1013.24ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1064.44ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1165.09ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# No
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 811.14ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# No
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 835.67ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1042.48ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1067.88ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1469.13ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1189.59ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1367.69ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1468.74ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1367.45ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1344.72ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1392.65ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1346.18ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1444.06ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1391.41ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1471.42ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1419.52ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1469.75ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1291.60ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1341.93ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1726.93ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1343.72ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# Yes
# No
# No
# No
# Yes
# No
# Yes
# Yes
# No
# No
# No
# Yes
# Yes
# No
# No
# Yes
# No
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 785.19ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1064.00ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1346.52ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 2105.70ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1317.04ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1342.83ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1596.45ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1316.78ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1368.38ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1471.13ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1448.30ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1317.53ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1316.68ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1345.12ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1320.85ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1497.66ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1521.00ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1317.99ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1317.23ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1316.68ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1322.11ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1393.15ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1650.95ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1322.34ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1849.03ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# Yes
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 785.88ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# No
# Yes
# No
# No
# No
# No
# Yes
# Yes
# No
# No
# No
# Yes
# No
# No
# No
# Yes
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 860.94ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1195.01ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1442.77ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1341.70ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1624.24ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1321.22ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1345.91ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1443.44ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1442.61ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1316.15ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1366.82ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1037.98ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1063.09ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1573.59ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1343.31ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1493.55ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1316.10ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1443.11ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1013.39ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1392.11ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1468.05ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1296.62ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1322.22ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1369.46ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# ...
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1342.16ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1341.54ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# No
# No
# No
# No
# No
# Yes
# Yes
# No
# No
# No
# Yes
# Yes
# No
# Yes
# Yes
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 810.19ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1094.20ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1366.87ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1341.19ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# No
# No
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 861.58ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1189.57ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1417.32ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1318.00ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1316.55ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1315.79ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1600.11ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1014.81ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1063.54ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1039.34ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1165.46ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1443.28ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1391.73ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1315.83ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1366.99ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1468.45ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1371.50ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1545.94ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1417.35ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1290.78ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1346.45ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1346.95ms
# 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# No
# No
# Yes
# Yes
# Yes
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-013640229a22> in <cell line: 30>()
#      30 for row,crow in zip(selected_columns,list_from_df):
#      31     row = "".join(row)
# ---> 32     resp = analyze_relevant_paper(row)
#      33     if(resp.lower() == "yes"):
#      34       identified_paper.append(crow)
#
# <ipython-input-22-013640229a22> in analyze_relevant_paper(text)
#      16                   #Answer yes or no.""";
#      17     try:
# ---> 18       keywords = model.generate_content(prompt)
#      19       text = keywords.text
#      20       print(text)
#
# /usr/local/lib/python3.10/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     256                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     257             else:
# --> 258                 response = self._client.generate_content(
#     259                     request,
#     260                     **request_options,
#
# /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py in generate_content(self, request, model, contents, retry, timeout, metadata)
#     810
#     811         # Send the request.
# --> 812         response = rpc(
#     813             request,
#     814             retry=retry,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, *args, **kwargs)
#     111             kwargs["metadata"] = metadata
#     112
# --> 113         return wrapped_func(*args, **kwargs)
#     114
#     115
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     347                 self._initial, self._maximum, multiplier=self._multiplier
#     348             )
# --> 349             return retry_target(
#     350                 target,
#     351                 self._predicate,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, timeout, on_error, **kwargs)
#     189     for sleep in sleep_generator:
#     190         try:
# --> 191             return target()
#     192
#     193         # pylint: disable=broad-except
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     118                 kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
#     119
# --> 120             return func(*args, **kwargs)
#     121
#     122         return func_with_timeout
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      70     def error_remapped_callable(*args, **kwargs):
#      71         try:
# ---> 72             return callable_(*args, **kwargs)
#      73         except grpc.RpcError as exc:
#      74             raise exceptions.from_grpc_error(exc) from exc
#
# /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py in __call__(self, request, retry, timeout, metadata)
#     833             headers = dict(metadata)
#     834             headers["Content-Type"] = "application/json"
# --> 835             response = getattr(self._session, method)(
#     836                 "{host}{uri}".format(host=self._host, uri=uri),
#     837                 timeout=timeout,
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in post(self, url, data, json, **kwargs)
#     635         """
#     636
# --> 637         return self.request("POST", url, data=data, json=json, **kwargs)
#     638
#     639     def put(self, url, data=None, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/google/auth/transport/requests.py in request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     539
#     540         with TimeoutGuard(remaining_time) as guard:
# --> 541             response = super(AuthorizedSession, self).request(
#     542                 method,
#     543                 url,
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535         # Receive the response from the server
#     536         try:
# --> 537             response = conn.getresponse()
#     538         except (BaseSSLError, OSError) as e:
#     539             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     459
#     460         # Get the response from http.client.HTTPConnection
# --> 461         httplib_response = super().getresponse()
#     462
#     463         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
print(len(identified_paper))
# Out:
# 53

# %%
identified_paper
# Out:
# [['Drought versus flood: What matters more to the performance of Sahel\nfarming systems?',
#   "Recent climate change has brought new patterns of extreme events in\nterms of both drought and heavy rainfall to the drought-prone African\nSahel. The effects of these recent extreme events on the performance of\nthe Sahel farming systems are still weakly investigated. This study aims\nat assessing effects of droughts versus floods on crop yield levels and\nlosses, focusing on the so-called recovery period, particularly\n2001-2020. A newly developed productivity-drought condition index (PDCI)\nis utilized to assess agricultural productivity as related to drought or\nflood in a highly vulnerable region, that is, the Sudanese Sahel. Four\nfarming systems, namely traditional rainfed, mechanized rainfed, gravity\nirrigated and spate irrigated systems, with sorghum and millet as staple\nfood crops, are considered. The PDCI is defined as a function of the\nintegrated normalized difference vegetation index (iNDVI) over the\ngrowing season. To address temporal and spatial variabilities, scaling\nof the PDCI is done in two dimensions: space and time. Crop statistics\nare used to derive yield losses. Our results show that both drought and\nflood episodes (seven and six episodes, respectively) can be captured\nusing the PDCI. Drought remains the most relevant risk to Sahel's crop\nproductivity. Some recent large-scale floods led to yield loss. However,\nfloods cause smaller risks to agricultural productivity compared to\ndroughts. Floods may even result in enhanced crop yields. Based upon\nscaling in the time or space domain, ranking the severity of drought\nimpacts on crop yield for individual years from 2001 to 2020 reveals\nleast to slightly different results. Vulnerability to drought depends on\nthe crop type and farming system. Drought effect on crop yield from the\nirrigated sector is clear on individual years but not as a general\nstatistical relationship. The parameter `percentage area under drought'\nexplains around one-third of the variation in the rainfed crop yield.\nThe spate irrigation scheme, the gravity irrigated system and the\nrainfed farmlands experienced respectively 87\\%, 57\\% and 46\\% of area\nunder drought on average. Irrigated systems produce much higher crop\nyields than rainfed systems. The mechanized system is more\ndrought-vulnerable than the traditional system. These results call for\nidentifying agricultural management pathways that recognize the combined\nimplications of both hydrological extremes for the region's food\nsecurity.\nA newly devised productivity-drought condition index (PDCI) based on\nintegrated normalized difference vegetation index (iNDVI) data is used\nto capture the performance of different Sahel farming systems. The\nperformance is evaluated spatially and temporally in a comparative study\nof effects of drought versus floods on crop yield levels and losses\nduring 2001-2020. Our research shows that: Crop productivity of all\nfarming systems is severely affected by drought; Flood events can also\nlead to a decline in productivity, but usually to a much lesser extent;\nThe vulnerability to droughts and floods depends upon the farming system\nand crop type. Our analysis shows that the farming systems in the\nSudanese Sahel have not reverted to conditions that could be described\nas a Sahel recovery. This study calls for agricultural management\ndecisions, which are specific for the different farming systems, in\nresponse to climate variability.image",
#   'drought; farming system; flood; normalized difference vegetation index;\nperformance; productivity-drought condition index; Sahel; yield loss',
#   '10.1002/hyp.14978',
#   'Article',
#   'SCALE IRRIGATION SYSTEMS; AGRICULTURAL DROUGHT; VEGETATION DYNAMICS;\nRISK-ASSESSMENT; AFRICAN SAHEL; RECENT TRENDS; CROP-YIELD; RAINFALL;\nCLIMATE; WATER'],
#  ["Arabic Semantic Similarity Approach for Farmers' Complaints",
#   "Semantic similarity is applied for many areas in Natural Language\nProcessing, such as information retrieval, text classification,\nplagiarism detection, and others. Many researchers used semantic\nsimilarity for English texts, but few used for Arabic due to the\nambiguity of Arabic concepts in both sense and morphology. Therefore,\nthe first contribution in this paper is developing a semantic similarity\napproach between Arabic sentences. Nowadays, the world faces a global\nproblem of coronavirus disease. In light of these circumstances and\ndistancing's imposition, it is difficult for farmers to physically\ncommunicate with agricultural experts to provide advice and find\nsuitable solutions for their agricultural complaints. In addition,\ntraditional practices still are used by most farmers. Thus, our second\ncontribution is helping the farmers solve their Arabic agricultural\ncomplaints using our proposed approach. The Latent Semantic Analysis\napproach is applied to retrieve the most problem-related semantic to a\nfarmer's complaint and find the related solution for the farmer. Two\nmethods are used in this approach as a weighting schema for data\nrepresentation are Term Frequency and Term Frequency-Inverse Document\nFrequency. The proposed model has also classified the big agricultural\ndataset and the submitted farmer complaint according to the crop type\nusing MapReduce Support Vector Machine to improve the performance of\nsemantic similarity results. The proposed approach's performance with\nTerm Frequency-Inverse Document Frequency-based Latent Semantic Analysis\nachieved better than its counterparts with an F-measure of 86.7\\%.",
#   "Semantic similarity; latent semantic analysis; big data; MapReduce SVM;\nCOVID-19; agriculture farmer's complaint",
#   nan,
#   'Article',
#   'MAPREDUCE'],
#  ['Functional homoeologous alleles of <i>CONSTANS</i> contribute to\nseasonal crop type in rapeseed',
#   'Key message Two CO paralogs in Brassica napus were confirmed and shown\ndistinct expression pattern and function in promoting flowering and\nallelic variation s within BnaCO.A10 were found closely associated with\necotype divergence. CONSTANS (CO) is a key gene that responds to\nphotoperiod and in Arabidopsis can promote flowering under long-day (LD)\nconditions. Brassica napus L. is a major oil crop and close relative of\nArabidopsis, and arose via allopolyploidization from the diploids B.\nrapa (A genome) and B. oleracea (C genome). In this study, we confirmed\nthat B. napus has two CO genes located on the A10 (BnaCO.A10) and C9\n(BnaCO.C9) chromosomes. Significant differences in level and temporal\npattern of transcription, as well as in protein function, of these\nhomoeologous may have resulted from sequence variation in the promoter\nas well as in the coding region. Apart from two insertions of 527 bp and\n2002 bp in the promoter of BnaCO.C9 that function as transcriptional\nenhancers, this gene is otherwise highly conserved in both promoter and\ncoding region. However, BnaCO.A10 was classified into two haplotypes and\ntransgene analysis in Arabidopsis and backcross analysis in rapeseed\nindicated that the winter-type haplotype had a greater effect in\npromoting flowering than the spring type. We discuss the contribution of\nCO alleles to species evolution, and for eco-geographic radiation\nfollowing crop domestication, alongside scope for managing this locus in\nfuture breeding.',
#   nan,
#   '10.1007/s00122-021-03896-x',
#   'Article; Early Access',
#   'FLOWERING-LOCUS-T; TIME GENE CONSTANS; NATURAL VARIATION; ARABIDOPSIS;\nBRASSICA; EVOLUTION; PROTEIN; GENOME; SELECTION; COMPLEX'],
#  ['Estimation of crop water stress index and leaf area index based on\nremote sensing data',
#   "Estimation of crop water stress index (CWSI) and leaf area index (LAI)\nover large-irrigation schemes requires the use of cutting-edge\ntechnologies. Combinations of remote sensing techniques with\nground-truth data have become available for use at the catchment level.\nThese approaches allow us to estimate actual evapotranspiration and have\nthe capability of monitoring crop water status and saving irrigation\nwater in water-scarce regions. This study was conducted in the Eastern\nMediterranean Region of Turkiye. Fully distributed CWSI maps were\ngenerated and we assessed the relationship between CWSI and the LAI for\nsome specific crops in the winter season of 2021. Landsat 7 and 8 data\nwere used and meteorological data were acquired from two stations in the\nstudy area. ``Mapping Evapotranspiration at high Resolution with\nInternalized Calibration' methodology was applied to estimate the energy\nbalance components. CWSI maps displayed spatio-temporal changes in\ntandem with crop-type variations. Consequently, results presented a high\ncorrelation (r 1/4 0.95 and r 1/4 0.99 for wheat and lettuce,\nrespectively) between CWSI and LAI, a moderate correlation (r 1/4 0.44)\nfor potatoes in the winter season. Thus, by utilizing remotely sensed\ndata, the CWSI values would be directly estimated without requiring any\nin situ measurements of the canopy and air temperature over-irrigation\nscheme.",
#   'actual evapotranspiration; artificial neural networks (ANNs); crop water\nstress index (CWSI); leaf area index (LAI); METRIC; remote sensing',
#   '10.2166/ws.2023.051',
#   'Article; Early Access',
#   'ENERGY-BALANCE; MAPPING EVAPOTRANSPIRATION; IRRIGATION; DRIP;\nTEMPERATURE; MANAGEMENT; CWSI'],
#  ['Agricultural land suitability classification and crop suggestion using\nmachine learning and spatial multicriteria decision analysis in\nsemi-arid ecosystem',
#   'Agricultural land evaluation for crop cultivation plays a vital role in\ndeveloping a sustainable and productive agricultural system. The\ntraditional way of manual land evaluation is time-consuming, costlier,\nrequires expert knowledge, and prone to human errors. The application of\nmachine learning is making its impact on almost every field. To overcome\nthe challenges of manual land evaluation automated approach of machine\nlearning can play an influential role in agriculture. Therefore, the\npresent study aimed to investigate and propose an automated solution for\nagricultural land suitability evaluation for two major crops, i.e.,\nwheat and mustered, based on a hybrid approach of multicriteria decision\nanalysis (MCDA) and machine learning (ML). The proposed framework is\nbased on the land suitability assessment framework proposed by the Food\nand Agriculture Organization (FAO). For evaluating suitability levels of\nland units, three major influential categories of geospatial parameters\nare considered, i.e., soil, climatic, and topographic. The MCDA\ntechnique of analytical hierarchy process (AHP) has been used to analyze\ncrop suitability utilizing these geospatial parameters. The ML models\nare constructed to map the quantified crop suitability results and\nsuggest the most suitable crop to be cultivated. The obtained results\nindicate that the Balanced Bagging classifier achieved the highest\nbalanced accuracies of 97.69\\% and 97.57\\% for mustered and wheat crop\nsuitability predictions, respectively, and a balanced accuracy of\n97.36\\% for crop classification. Since the AHP method is a systematic\napproach to decision analysis, while ML is a data-driven approach, the\nproposed unified approach offers more comprehensive predictions. The\npotential of the proposed framework is evaluated for the Abhanpur\ndistrict of Chhattisgarh state, India. The proposed ML-based approach\novercomes the limitations of the conventional methods and provides\nprecise decisions; therefore, could turn the attention to ML in future\ncropland suitability evaluation studies.',
#   'Analytical hierarchy process; Machine learning; Crop selection; Land\nsuitability analysis; Semi-arid ecosystem; Geographic information\nsystem; Agricultural crops',
#   '10.1007/s10668-023-04440-1',
#   'Article; Early Access',
#   'SOIL; SYSTEM; RECOMMENDATION; PREDICTION; MICROLEIS'],
#  ['Root-Lesion Nematodes Affecting Dryland Cereals in the Semiarid Pacific\nNorthwest USA',
#   "Root-lesion nematodes (Pratylenchus spp.) are parasites that invade and\ndeteriorate roots, thereby reducing the efficiency of water and nutrient\nuptake. Pratylenchus neglectus and P. thornei are the two species that\nare most prevalent and cause reduced yields of rainfed wheat and barley\nin semiarid regions of the Pacific Northwest. They are particularly\ndamaging where wheat and barley are produced without irrigation in areas\nreceiving less than 450 mm (18 in.) of precipitation annually. This\nreview is focused on the biology and management of P. neglectus and P.\nthornei in semiarid rainfed agriculture. Characteristics of climates,\nsoils, and crop production systems are described as a preface to\nconstraints placed upon management options. Discussions include the\neconomic importance, host ranges, and protocols for sampling and species\nidentification. Discussion of disease management options include crop\nrotation, genetic resistance and tolerance, planting date, trap and\nbiofumigant crops, crop nutrition, chemical and biological nematicides,\nand tillage. Predictions for rainfed agriculture in a period of changing\nclimate are presented, as are suggestions for important areas of\nresearch including crop genetics, nematode testing, and communication of\nresults, Pratylenchus biology, mechanisms of resistance, the phytobiome,\nand closing the ``yield gap{''} between actual and attainable yields.",
#   'cereals and grains; crop type; cultural and biological practices;\ndisease management; field crops; fungi; nematodes; pathogen detection;\ntechniques',
#   '10.1094/PDIS-04-21-0883-FE',
#   'Article',
#   'PLANT-PARASITIC NEMATODES; QUANTITATIVE TRAIT LOCI; SYNTHETIC HEXAPLOID\nWHEAT; SOIL-BORNE PATHOGENS; LONG-TERM TILLAGE; PRATYLENCHUS-THORNEI;\nP-THORNEI; SPRING WHEAT; CROPPING SYSTEMS; WINTER-WHEAT'],
#  ['Methodology for groundnut discrimination based on timeseries of\ndual-polarimetric SAR parameters',
#   'The groundnut, also known as peanut, is a legume crop that is classified\nas both a grain legume and an oil crop (due to its high oil content).\nAbout 85\\% of the total groundnut in India is sown in the kharif season\nunder rainfed conditions. This makes it extremely difficult to apply the\noptical remote sensing methodologies for groundnut discrimination and\nacreage estimation. We develop a remote sensing strategy based on\ntimeseries synthetic aperture radar (SAR) imagery, which is immune to\nthe rainy conditions of the observation period. Further, our work is\ndistinct from the traditional multitemporal SAR backscatter analysis as\nit incorporates polarimetric parameters such as the alpha angle (a) and\nthe polarimetric radar vegetation index to aid discrimination. These\nparameters were shortlisted on the basis of maximal sensitivity to\ngroundnut growth stages. Random forest classifier, an ensemble\nlearning-based classifier, is used to carryout the crop classification\nusing these parameters. This approach is contrasted with SAR\nbackscatter-based analysis (using the same RF classifier) and with a\nEuclidean distance (ED)-based model matching method (with the same\npolarimetric parameters). A detailed comparative analysis of\nclassification accuracy of groundnut discrimination is carried out using\nextensive ground truth data over the agricultural fields of Junagadh\ndistrict in the Gujarat state of Western India. The backscatter-based\nanalysis with RF achieves 86.2\\% overall accuracy in discriminating\ngroundnut (with the competing cotton crop), whereas polarimetric\nparameters with ED model matching achieves 76\\%. Using the proposed\nmethod, with dual-pol parameters derived out of Sentinel-1 SAR data, we\nreport 92.7\\% overall accuracy with a kappa coefficient of 0.81. The\nmajor insight is that combining timeseries polarimetric information\ntogether with a good machine learning classifier improves the\nclassification accuracy of short crops compared to nonpolarimetric\napproach. (C) 2022 Society of Photo-Optical Instrumentation Engineers\n(SPIE)',
#   'dual-polarimetric SAR parameters; timesereis SAR polarimetry; groundnut\ndiscrimination; random forest classifier',
#   '10.1117/1.JRS.16.018505',
#   'Article',
#   'CLASSIFICATION'],
#  ['Cover Crops and No-Tillage Show Negligible Effects on Grapevine\nPhysiology in two different California Vineyard Agroecosystems',
#   'This study evaluated the effects of annual or perennial cover crops and\ntillage regimes on whole grapevine physiology and berry composition. We\nstudied the interactive effects of tillage and cover crops on grapevine\nwater status, leaf gas exchange, components of yield, berry composition\nand resulting water footprint in two contrasting production regions\n(Fresno County-hot climate and Napa County-warm climate) of California.\nThe treatments included perennial grass (PG), resident vegetation (RV),\nand an annual grass (AG) grown under conventional tillage (CT) and\nno-till (NT) settings. Neither cover crop nor tillage affected grapevine\nleaf gas exchange. However, at the Napa County vineyard, NT\ndetrimentally affected grapevine water status compared to CT. Grapevine\nmineral nutrition, when assessed during anthesis, revealed no effects of\ncover cropping in either year or at either location. Cover crop type did\nnot affect yield components or berry composition; however, CT increased\ntitratable acidity (TA) at both sites. The water footprint of vineyards\nat either location was not affected by cover crops or tillage. Under our\nexperimental conditions, it was evidenced that both in a hot and warm\nclimate, vineyard cover cropping had negligible beneficial effects on\ngrapevine physiology, mineral nutrition or productivity with no\ndetrimental effects on vineyard water footprint. Furthermore, this study\nshowed that tillage was beneficial in younger vineyards to improve plant\nwater status in semi-arid regions.',
#   'grape composition; nutrients; yield components; vineyard management;\nwater status',
#   '10.20870/oeno-one.2023.57.2.7136',
#   'Article',
#   'FLOOR MANAGEMENT-PRACTICES; SOIL CARBON SEQUESTRATION;\nCABERNET-SAUVIGNON; VEGETATIVE GROWTH; MEDITERRANEAN CONDITIONS;\nPERENNIAL GRASSES; CLIMATE-CHANGE; WATER; YIELD; NITROGEN'],
#  ['Conservation Strip Tillage Leads to Persistent Alterations in the\nRhizosphere Microbiota of <i>Brassica napus</i> Crops',
#   "Microbes play vital roles in many soil ecosystem functions and services,\nwhich are crucial for agricultural productivity. Among different\nagricultural management practices, soil tillage methods can result in\nchanges in a soil's physical, chemical and biological properties,\nincluding the soil microbiome. In addition, crop type and the plant\ndevelopmental stage are important drivers of rhizosphere bacterial\nmicrobiota structure and composition. Here, we have used\nhigh-throughput, 16S amplicon sequencing to explore the rhizosphere\nbacterial structure and composition of Brassica napus (winter oilseed\nrape) in two contrasting tillage practices; conventional-plough based\ntillage and conservation strip tillage, over three different plant\ngrowth stages (vegetative, flowering and harvesting stage). This was the\nfirst year that conservation strip tillage was used in this field, as in\nprevious years plough based tillage practices has been used. Our\nfindings show that tillage and growth stages were important determinants\nof microbial community structure and composition, but the effect of\ntillage became stronger at plant maturity. The combined effect of\nconservation strip tillage and harvesting stage had a impact on the\nrhizosphere microbiota selection. The rhizosphere bacterial community of\nwinter oilseed rape under conservation strip tillage was different to\nthat under conventional tillage. Our data suggests that different\ntillage regimes created distinct ecological niches that selected\ndifferent microbiota with potential consequences for the ecosystem\nservices provided to the plants and the soil environment.",
#   'tillage; oilseed rape; rhizosphere; microbiota; plant growth stages;\nnext generation sequencing; 16S rRNA gene',
#   '10.3389/fsoil.2021.659454',
#   'Article',
#   'COMMUNITY STRUCTURE; BACTERIAL COMMUNITIES; RELATIVE IMPACTS; SOIL;\nDIVERSITY; DYNAMICS; PLANT; ROTATION; MANAGEMENT; SEQUENCES'],
#  ['Deep Learning-Based Estimation of Crop Biophysical Parameters Using\nMulti-Source and Multi-Temporal Remote Sensing Observations',
#   "Remote sensing data are considered as one of the primary data sources\nfor precise agriculture. Several studies have demonstrated the excellent\ncapability of radar and optical imagery for crop mapping and biophysical\nparameter estimation. This paper aims at modeling the crop biophysical\nparameters, e.g., Leaf Area Index (LAI) and biomass, using a combination\nof radar and optical Earth observations. We extracted several radar\nfeatures from polarimetric Synthetic Aperture Radar (SAR) data and\nVegetation Indices (VIs) from optical images to model crops' LAI and dry\nbiomass. Then, the mutual correlations between these features and Random\nForest feature importance were calculated. We considered two scenarios\nto estimate crop parameters. First, Machine Learning (ML) algorithms,\ne.g., Support Vector Regression (SVR), Random Forest (RF), Gradient\nBoosting (GB), and Extreme Gradient Boosting (XGB), were utilized to\nestimate two crop biophysical parameters. To this end, crops' dry\nbiomass and LAI were estimated using three input data; (1) SAR\npolarimetric features; (2) spectral VIs; (3) integrating both SAR and\noptical features. Second, a deep artificial neural network was created.\nThese input data were fed to the mentioned algorithms and evaluated\nusing the in-situ measurements. These observations of three cash crops,\nincluding soybean, corn, and canola, have been collected over Manitoba,\nCanada, during the Soil Moisture Active Validation Experimental 2012\n(SMAPVEX-12) campaign. The results showed that GB and XGB have great\npotential in parameter estimation and remarkably improved accuracy. Our\nresults also demonstrated a significant improvement in the dry biomass\nand LAI estimation compared to the previous studies. For LAI, the\nvalidation Root Mean Square Error (RMSE) was reported as 0.557 m(2)/m(2)\nfor canola using GB, and 0.298 m(2)/m(2) for corn using GB, 0.233\nm(2)/m(2) for soybean using XGB. RMSE was reported for dry biomass as\n26.29 g/m(2) for canola utilizing SVR, 57.97 g/m(2) for corn using RF,\nand 5.00 g/m(2) for soybean using GB. The results revealed that the deep\nartificial neural network had a better potential to estimate crop\nparameters than the ML algorithms.",
#   'crop biomass; Leaf Area Index; Earth observations; Synthetic Aperture\nRadar; optical images; machine learning algorithms; SMAPVEX-12',
#   '10.3390/agronomy11071363',
#   'Article',
#   'LEAF-AREA INDEX; VEGETATION INDEXES; RANDOM FOREST; BIOMASS; SAR; CORN;\nREGRESSION; MOISTURE; YIELD; WHEAT'],
#  ['Monitoring rice lodging grade via Sentinel-2A images based on change\nvector analysis',
#   'Lodging stress influences the yield, quality, and mechanical harvesting\nability of rice (Oryza sativa L.). It is of great significance for the\nquantitative and objective evaluation of rice yield loss to obtain the\nrice lodging distribution and grade information rapidly and\nnondestructively. The purpose of this paper was to establish a remote\nsensing monitoring method for the grade of rice lodging based on change\nvector analysis via Sentinel-2A images before and after lodging. Taking\nthe lodging ratio (LR) of rice in the parcel as the characterization\nindex, the changes in spectral reflectance and vegetation index of the\nrice canopy under different lodging grade stresses were analyzed. A\n7-dimensional space vector was composed of a canopy spectral reflectance\nand vegetation index. A new angle vector was formed by the angle between\neach vector object and the axis of the canopy spectrum (vegetation\nindex). Based on the difference in feature vectors before and after\nlodging, a lodging grade monitoring model based on rice parcels was\nconstructed, and the accuracy of the model was verified using field\nobservations. The results showed that the spectral reflectance of the\nrice canopy after lodging increased with the increase in lodging stress.\nThe difference in vegetation index before and after lodging increased\nwith the increase in lodging severity. Based on the change in the\nmagnitude of the canopy spectral reflectance and its angle vector, and\nthe vegetation index and its angle vector, the R ( 2 ) of the rice\nlodging model was 0.66, 0.66, 0.60, and 0.59, respectively, and the RMSE\nvalues were 21.03\\%, 20.37\\%, 22.13\\%, and 22.84\\%, respectively.\nTherefore, the accuracy of the model constructed using the vegetation\nindex was the highest. The canopy spectral reflectance and difference in\nthe vegetation index of rice changed regularly with lodging grade\nstress. The model based on the change magnitude of the vegetation index\ncould effectively realize remote sensing monitoring of the grade of rice\nlodging in Wuchang.',
#   'rice; lodging grade; parcel; Sentinel-2A; change vector analysis (CVA)',
#   '10.1080/01431161.2021.2012293',
#   'Article',
#   'LAND-COVER CHANGE; CROP CLASSIFICATION; SPECTRAL REFLECTANCE; YIELD\nLOSSES; VEGETATION; INDEX; WHEAT; LANDSCAPES; PERFORMANCE; RESISTANCE'],
#  ['IMPACT OF CLIMATE CHANGE ON THE AREA OF MAJOR CROPS',
#   "In this work, a statistical analysis of the time series of areas of\nmajoritarian crops for 20 years (from 1998 to 2020) is carried out, and\nthe influence of agro-climatic zones on the area of cultivation of major\ncrops is analyzed. Climate change is acutely felt in the southern\nregions of Ukraine, increasing the production risk in the agricultural\nsector through changes in temperature, precipitation, and other extreme\nweather events. Historical climatic data indicate an increase in\ntemperature on the territory of Ukraine, and climate forecasts suggest\nfurther warming, especially in the south of Ukraine.\nUsing satellite and statistical data, changes in the earth's surface are\ninvestigated for certain areas, which are characterized by the greatest\nchanges in crop areas for the main types of crops. To analyze the\ndynamics of cultivated areas in relation to climatic zones, we used\nnational statistical data for 1998-2019, maps of the classification of\nland cover from 2016-2020, data on climatic zones on the territory of\nUkraine for 2000 and 2020, as well as the contours of administrative\nunits of the NUTS2 level. Since statistical data for many districts are\nnot available for the period 2019-2020 due to the reform of territorial\nboundaries, we used instead cultivated areas obtained from open\nsatellite records. As additional and alternative information for the\nanalysis of acreage, crop classification maps for 2016-2020 were used,\nobtained by specialists of the Space Research Institute of the National\nAcademy of Sciences of Ukraine and the State Space Agency of Ukraine\nfrom their own in-depth training technologies.\nWe used classification maps obtained using open satellite data of the\nCopernicus program: SAR Sentinel-1 and Sentinel-2 with a spatial\nresolution of 10 m. A comparison of statistical data and crop areas\nobtained from satellite data was carried out by applying the metric of\nstatistical analysis of the correlation coefficient (r). To assess the\naccuracy, the coefficient of determination R-2 between the statistical\narea of the main crops and the area according to satellite data was also\napplied.",
#   'climate change; satellite data; deep learning; classification maps;\nSentinel-1; Sentinel-2',
#   '10.15407/knit2022.02.030',
#   'Article',
#   'UKRAINE; YIELDS'],
#  ['A paradigm of GIS and remote sensing for crop water deficit assessment\nin near real time to improve irrigation distribution plan',
#   "This study comprehensively used Remote Sensing (RS) and GIS for\nindependently monitoring crop water adequacy in response to existing\nirrigation management system in Bari Doab, Pakistan. Canals' rotation\nplan is developed before start of each cropping season to distribute\nwater on fixed turn basis. The study combines the moderate (Landsat-8)\nand low resolution (MODIS) satellite imagery to assess near real time\ncrop water deficit in canal command areas (CCAs) of the study area.\nLandsat imagery were used to develop crop classification and determine\ncropping pattern using time series of NDVI. MODIS' NDVI product was\nemployed to monitor the current crop health and develop annual reference\nNDVI cycle based on last 13 years' imagery. Climatic data of WMO\nstations combined with DEM have also been used to determine reference\nevapotranspiration based on Penman-Monteith method. These inputs were\ncombined to estimate average crop water deficit in CCAs for ongoing\ncropping season on 08-day interval, the interval parallel to the canal\nrotation plan. RS based reflectance crop coefficients (K-CR) of current\nand reference crop cycle were developed to calculate potential and\nactual evapotranspiration, and then translated their difference into\ncrop water deficit. Lag time of 08-10 days is limitation of the study\ndue to satellites overpass time, but it can still prove very helpful\nconsidering the crop season spanned over 160-180 days. Results revealed\nthat maximum crop water deficit (up to 9 mm) occurred in CCAs during\ncrop growing (mid) stage. Crop water deficit showed inverse relation\nwhen plotted against intense rainfall months. Crop water deficit results\ncould be helpful for irrigation managers to modify canals' rotation plan\nin near real time according to crop health and growing stage. It would\nnot only help in achieving equitable water distribution but also\nassuring supplies when required by the crops.",
#   'Crop water deficit; Remote sensing; Evapotranspiration; NDVI (Normalized\nDifference Vegetation Index); Crop coefficients; Canal command area',
#   '10.1016/j.agwat.2020.106443',
#   'Article',
#   'RANGELAND VEGETATION TYPE; SOLAR-RADIATION; EVAPOTRANSPIRATION;\nPRODUCTIVITY; COEFFICIENTS; SERIES; REQUIREMENTS; PERFORMANCE;\nMANAGEMENT; HUMIDITY'],
#  ['Rhizosphere bacterial community structure of three minor grain crops: A\ncase-study from paired field sites in northern China',
#   'Rhizosphere bacteria are critical to plant health and ecological\nfunctioning. However, our understanding of rhizosphere bacterial\ncommunity turnover and co-occurrences with minor grain crops remains\nlimited, especially at regional scales. Herein, we compared the turnover\nand networks of foxtail millet, proso millet, and sorghum rhizosphere\nbacterial communities across nine paired fields in northern China.\nRemarkable differences in community composition, diversity between three\nminor grain crops, and the influence of region on these indicators was\ngreater than that of crop type. Community richness of foxtial millet,\nproso millet, and sorgum showed a unimodal curve with latitude\nincreased. Compared to spatial factors, environmental variables had\ngreater effects on the rhizosphere bacterial community turnover in three\nminor grain crops. Edaphic variables were more important than climatic\nvariables for rhizosphere bacterial community composition in foxtail\nmillet fields. In addition, soil organic matter (OM) and total nitrogen\n(TN) were the key factors influencing the turnover of rhizosphere\ncommunities in foxtail millet and sorghum. In contrast, pH and TN were\nimportant factors influencing the turnover of rhizosphere communities in\nproso millet. Rhizosphere bacterial networks were more closely\ninterconnected in proso millet fields than in the other two crops,\nshowing the lower average path length and diameter, greater average\nclustering, and graph density. In addition, Proteobacteria,\nActinobacteria, and Acidobacteria played major roles in the rhizosphere\nbacterial network structures and were predicted to maintain generalist\nmetabolic diversity. These findings provide new insights for expanding\nour knowledge of the biogeography and coexistence theory of minor grain\ncrop ecosystems at a large scale.',
#   'community structure; ecological turnover; minor grain crops; northern\nChina; rhizosphere bacteria',
#   '10.1002/ldr.4132',
#   'Article; Early Access',
#   'COOCCURRENCE PATTERNS; MICROBIAL COMMUNITIES; ASSOCIATION NETWORKS; SOIL\nTYPE; DIVERSITY; MODULARITY; PLANT; FERTILIZATION; INSIGHT; ROOTS'],
#  ['Cover crops can produce livestock forage in Chinese subtropical regions',
#   'It is common in South China that rice (Oryza sativa L.) fields are\nseeded with a cover crop following autumn harvest. The objective was to\ncompare the effects of different no-tillage methods on cover crop yield,\nnutritive composition, and silage fermentation quality of forage wheat\n(Triticum aestivum L. cv. Shimai-1) and Italian ryegrass (Lolium\nmultiflorum L.). Cover crops were planted in winter fallow paddy fields\n9 (NT9) and 5 (NT5) d prior to rice harvest and 1 d after rice harvest.\nCover crops seeded prior to harvest were no-tillage planted and cover\ncrops seeded after rice harvest were either no-tillage (NT1) or seeded\nusing conventional techniques (CT1; plow followed by seeding). The cover\ncrop biomass was determined before rice sowing in spring. Compared to\nNT9 and NT5, the dry matter (DM) and crude protein (CP) yields of NT1\nand CT1 were slightly higher. Compared to Italian ryegrass, forage wheat\nhad high relative feed value and DM yield. The neutral detergent fiber\nconcentration of NT9 and NT5 was higher than NT1 and CT1 (P < .05),\nwhereas the water-soluble carbohydrates (WSC) concentration was lower\nthan NT1 and CT1 (P < .05). The CP, crude fiber, and WSC concentrations\nof forage wheat were lower than Italian ryegrass (P < .05). Interaction\nbetween years and cover crop type were observed in silage fermentation\nquality (P < .05). The best sowing method for forage wheat and Italian\nryegrass on winter fallow paddy fields was no-tillage sowing after rice\nharvest, based upon the present study.',
#   nan,
#   '10.1002/agj2.20619',
#   'Article; Early Access',
#   'WATER-USE EFFICIENCY; RICE-WHEAT ROTATION; WINTER-WHEAT; NO-TILL; YIELD\nCOMPONENTS; CROPPING SYSTEM; NUTRITIVE-VALUE; SOIL; SILAGE; QUALITY'],
#  ['Cytogenetic toxicity from pesticide and trace element mixtures in soils\nused for conventional and organic crops of <i>Allium cepa</i> L',
#   'Pesticides and trace elements occur in complex mixtures in\nagroecosystems, affecting soil health and food security. Hence, it is\nnecessary to determine their toxicity in field conditions and to develop\nmonitoring approaches to assess conventional and organic agriculture.\nThe aim of this research was to evaluate the associations between Allium\ncepa L. cytogenetic biomarkers and the realistic mixture of pesticides\nand trace elements found in soils of conventional, conversion, and\norganic crops in an intensive agricultural region in Colombia. Pesticide\nscreening was conducted using GC-MS/MS and LC-MS/MS methods. Arsenic,\ncadmium, lead, and zinc were analyzed by ICP-MS; chromium, copper,\nnickel, and selenium by ICP-OES; and mercury by a direct analyzer. The\nmeristematic cells in roots of Allium cepa L. were analyzed through\nmicroscopic observations to quantify cytogenetic effects. In\nconventional crops, 26 pesticides were detected in the soil samples, and\nthose were below the limit of quantification in organic crops. The mean\nlevels of As, Cd, Cr, Ni, Pb, and Se were also greater in soils of\nconventional crops compared to the organics. In addition, the biomarkers\nof cytotoxicity and genotoxicity appeared augmented in conventional\nsamples, and those were correlated with pesticide and trace element\nconcentrations, pollution indices, and hazard quotients. Subsequently, a\ndiscriminant function based on the mitotic index, chromosomal\naberrations, and nuclear abnormalities was suitable to classify the\nsamples by crop type. These results demonstrate the sensitivity of\nAllium cepa L. to the toxicity of complex mixtures in field crops and\nits potential as an in-situ approach for soil health monitoring in\norganic and conventional crop systems. (C) 2021 Elsevier Ltd. All rights\nreserved.',
#   'Biomonitoring; Discriminant analysis; Ecological risk; Genotoxicity;\nOrganic agriculture',
#   '10.1016/j.envpol.2021.116558',
#   'Article; Early Access',
#   nan],
#  ['Driving forces of nitrogen use efficiency in Chinese croplands on county\nscale',
#   'Nitrogen use efficiency (NUE, defined as the fraction of N input\nharvested as product) is an important indicator to understand nitrogen\nuse and losses in croplands as an element of determining sustainable\nfood production. China, as the country with the largest amount of\nnitrogen fertilizer use globally, research into NUE consistently finds\nit to be much lower than that in developed countries. Understanding the\ndriving forces of the underlying causes of this low NUE is thus crucial\nto improve nitrogen use and reduce losses in China. Here we applied the\nCHANS model to estimate cropland NUE for over 2800 counties in China for\nthe year 2017. Results showed that in most counties NUE ranged between\n20\\% and 40\\%, while an NUE >50\\% was mainly found in Northeastern\nChina, likely as a result of large-scale, modern agriculture operations.\nThe source of N input and crop types significantly affected NUE in our\nassessment. Nitrogen deposition, straw recycling, and biological\nnitrogen fixation (BNF) could improve NUE, while chemical nitrogen\nfertilizer and manure inputs reduce NUE. Grain crops have a much higher\nNUE compared to vegetables, which are often over-fertilized. Moreover,\nNUE in Southern China is strongly influenced by natural factors such as\ntemperature and precipitation. Specifically, NUE in the Yangtze River\nDelta (eastern coastal region of China) is associated with\nsocio-economic factors including GDP and the degree of urbanization,\nwhile in North-central China, NUE is mainly determined by nitrogen input\nsources. These examples illustrate that approaches aiming at improving\nNUE need to be location-specific with consideration of multiple natural\nand socioeconomic factors.',
#   'NUE; Nitrogen source; Driving force; Environmental pollution; Crop type',
#   '10.1016/j.envpol.2022.120610',
#   'Article; Early Access',
#   'WATER PRODUCTIVITY; FOOD SECURITY; CROP; MANAGEMENT; LIVESTOCK; YIELD;\nFERTILIZATION; AGRICULTURE; PHOSPHORUS; RESOLUTION'],
#  ['Research on a method for diagnosing clogging faults and longitudinal\naxial flow in the threshing cylinders of drum harvesters',
#   'Here we present a high-precision method for predicting threshing drum\nclogging in drum harvesters, with strong applicability for longitudinal\naxial flow in crawlers. This method can be used to determine the alarm\nthreshold. It entails placing a wireless vibration sensor at the outer\nend of the rotary shaft of the harvester to collect axial vibration\nsignals from the drum to detect early fault characteristics. The method\nemploys the Hilbert-Huang transform-analysis method to obtain\ntime-frequency spectrum characteristics of the blocking process, thus\ndiagnosing the speed reduction necessary to shut down when the threshing\ndrum is clogged. The traditional method of extracting fault\ncharacteristic frequency by Fourier transform is compared with the\nproposed method. This method can not only diagnose the critical value of\nthe rotating speed when the drum is clogged but also accurately and\nclearly reflect the trend of the drum clogging fault. The fault is\nwithin 3 standard deviations above or below the mean characteristic\nfrequency, and abnormality is with in 1 standard deviation above or\nbelow the mean characteristic frequency. Based on our experimental\nanalysis, we introduce the concept of the confidence interval, and we\nconsider crop type and the diversity of working conditions. The proposed\nmethod improves the adaptability of forecasting to specific environments\nand combines agricultural machinery with agronomy. The trend of blocking\ncan be predicted at least 1 s in the early stage of blockage by using a\nsliding window to process the vibration data collected in real time.\nThis predictive ability makes the method superior to speed-sensor\nanalysis in precision. (C) 2021 Institute of Noise Control Engineering.',
#   nan,
#   nan,
#   'Article',
#   nan],
#  ['The dissemination of antibiotics and their corresponding resistance\ngenes in treated effluent-soil-crops continuum, and the effect of\nbarriers',
#   'Irrigation with treated effluent is expanding as freshwater sources\ndiminish, but hampered by growing concerns of pharmaceuticals\ncontamination, specifically antibiotics and resistance determinants. To\nevaluate this concern, freshwater and effluent were applied to an open\nfield that was treated with soil barriers including plastic mulch\ntogether with surface and subsurface drip irrigation, cultivating\nfreshly eaten crops (cucumbers or melons) for two consecutive growing\nseasons. We hypothesized that the effluent carries antibiotics and\nresistance determinants to the drip-irrigated soil and crops regardless\nof the treatment. To test our hypothesis, we monitored for antibiotics\nabundance (erythromycin, sulfamethoxazole, tetracycline,\nchlortetracycline, oxytetracydine, amoxicillin, and ofloxacin) and their\ncorresponding resistance genes (ermB, ermF, sul1, tetW, tetO, bla(TEM)\nand qnrB), together with class 1 integron (intl1), and bacterial 16S\nrRNA, in water, soil, and crop samples taken over two years of\ncultivation. The results showed that an array of antibiotics and their\ncorresponding resistance genes were detected in the effluent but not the\nfreshwater. Yet, there were no significant differences in the\ndistribution or abundance of antibiotics and resistance genes,\nregardless of the irrigation water quality, or crop type (p > 0.05), but\nplastic-covered soil irrigated with effluent retained the antibiotics\noxytetracydine and ofloxacin (p < 0.05). However, we could not detect\nsignificant correlations between the detected antibiotics and the\ncorresponding resistance genes. Overall, our findings disproved our\nhypothesis suggesting that treated effluent may not carry antibiotics\nresistance genes to the irrigated soil and crops yet, plastic mulch\ncovered soil retain some antibiotics that may inflict long term\ncontamination. (C) 2021 Elsevier B.V. All rights reserved.',
#   'Treated wastewater; Antibiotics; Resistance genes; Agriculture; Plastic\nmulch; Drip irrigation',
#   '10.1016/j.scitotenv.2021.151525',
#   'Article; Early Access',
#   'WATER TREATMENT PLANTS; WASTE-WATER; EMERGING CONTAMINANTS; ADSORPTION\nBEHAVIOR; IRRIGATION; BACTERIA; FATE; ENVIRONMENT; PATHOGENS; POLLUTION'],
#  ['The occurrence and distributions characteristics of microplastics in\nsoils of different land use patterns in Karst Plateau, Southwest China',
#   'Microplastics (MPs) in soils have attracted attention worldwide.\nHowever, there are few studies on the abundance and morphological\ncharacteristics of MPs under different land use patterns in karst areas.\nIn this work, the distribution characteristics of MPs in soils from five\ndifferent land use patterns, including industrial mining warehouse (IW),\ncropland (CL), forest land (FL), grassland (GL), and garden land (GP) in\nkarst mountainous areas of southwest China were investigated. The\nresults suggested that soils in Karst Plateau of Guizhou province under\ndifferent land use patterns have all been polluted by MPs. The average\nmicroplastic abundances of IW, CL, FL, GL, and GP were 3114, 2948, 2770,\n2718, and 4200 item kg- 1. In the GP and GL soils, foam was the dominant\nform of MPs (47.53 \\% and 45.92 \\%), with pellet MPs accounting for the\nsmallest proportion, while in IW, CL, and FL soils showed the opposite\nresult. The MPs in all soil samples were dominated by small particles\n(0-0.5 mm), and the main components were PE, PP, PVC, and PET.\nMeanwhile, the characteristics of MPs in CL soils varied depending on\nthe planted crops. The average abundances of soil microplastics in\nfarmlands planted with corn, pepper, cabbage, watermelon, and other\ncrops were 2504, 2792, 2987, 2370, and 3655 item kg -1. We suggested\nthat land use pattern and crop type may influence karst soil\nmicroplastic contamination. The results of this study provide a\nscientific basis for understanding and controlling the distribution,\ndegradation, and migration of MP pollution in karst regions.',
#   'Microplastics; Land use patterns; Karst Plateau; Soil',
#   '10.1016/j.scitotenv.2023.167651',
#   'Article; Early Access',
#   nan],
#  ['How much agricultural land is there close to residential areas? An\nassessment at the national scale in France',
#   "In 2019, aiming at reducing resident's exposure to pesticides, the\nFrench government announced mandatory pesticide-free buffer zones of\n3-20 m around inhabited areas. As pesticide reduction is often\nassociated with lower productivity, this raised questions about the\namount of agricultural area located around residential buildings, which\nhas not yet been quantified in France. The best available data\ndescribing spatial organization of crops at the field parcel scale and\nlocation of residential buildings over the whole French territory were\ncombined to calculate the amount of agricultural area within 10 m, 50 m,\n100 m, and 150 m (a distance advocated by some environmental NGOs) to\nresidential buildings for 23 crop types. Results show that 0.2\\%, 5\\%,\n16\\%, and 29\\% of the total national agricultural area is located within\n10 m, 50 m, 100 m, and 150 m to residential buildings, respectively. The\nproportion of crop-specific national area that is close to housings is\nlow at 10 m (0-1\\%) and increases up to 10-58\\% depending on crop type\nat 150 m. About 32\\%-45\\% of vineyards and 37\\%-53\\% of or-chards\nnational area, two crop types with high pesticide use intensity, are\nlocated within 150 m to residential buildings. We conclude that (i) the\nimplementation of pesticide-free buffer zones around housings may have a\nstrong impact on agricultural production at the national scale because\nof likely associated yield and quality losses on large areas, and (ii)\nthe large presence of treated crops close to residential buildings\nrequires attention for its potential effect on residents' exposure to\npesticides.",
#   'Pesticides; Agriculture; Exposure; Residents; Pesticide -free buffer\nzones; France',
#   '10.1016/j.buildenv.2022.109662',
#   'Article; Early Access',
#   'PESTICIDE USE; GRAPEVINE; EXPOSURE; PROTECTION; MANAGEMENT; QUALITY;\nIMPACTS; SYSTEM; DOWNY; CROPS'],
#  ["Farmers' Knowledge, Attitudes, and Control Practices of Rodents in an\nAgricultural Area of Taiwan",
# ...
#   'APSIM; Post-rainy; Sorghum; GxExM; Agri-system design',
#   '10.1016/j.fcr.2021.108422',
#   'Article; Early Access',
#   'AFFECTING GRAIN-SORGHUM; ENVIRONMENT INTERACTIONS; DROUGHT STRESS; YIELD\nGAP; GENOTYPE; MODEL; PATTERNS; EASTERN; CROPS; IMPROVEMENT'],
#  ['Occurrence, distribution, and driving factors of current-use pesticides\nin commonly cultivated crops and their potential risks to non-target\norganisms: A case study in Hainan, China',
#   "Multiple pesticides are heavily applied in crops grown in China's\ntropics due to the prevalence of diseases and pests, thus posing\npotential risks to nontarget organisms (e.g., honeybees, lacewings,\nladybugs, and humans). However, there is little information on this\ntopic. This study is the first assessment of the occurrence, driving\nfactors, and ecological/human health risks of 32 current-use pesticides\n(CUPs) in 10 frequently-planted crops collected from practicing\nrice-vegetable rotation systems in Hainan, China. Of the 132 whole crop\nsamples, 44 (33.3 \\%) residues from >= 8 pesticides were detected in\n9.09 \\% of crop samples with concentrations >= 0.5 mg kg(-1). Six\npesticide residues, namely carbendazim, pyraclostrobin, acetamiprid,\nthiophanate methyl, phoxim, and imidacloprid, were detected in 72.7 \\%\nof samples, with concentrations ranging from 0.0021 to 13.5 (median =\n0.032) mg kg(-1). Among them, carbendazim, pyraclostrobin, and\nacetamiprid were the most common, contributions from 10.2 to 25.5 \\% and\na detection frequency ranging from 25.6 to 56.1 \\%. The order of total\nconcentration of 32 CUPs ( n-expressionry sumexpressiontion 32 CUP)\nconcentrations during the year was January > May > November > August and\nvegetables > rice, being highly related with pesticides usage pattern,\ncrop type, plant accumulation/dissipation and plant lipid contents. The\necological risk quotients (RQs) to four beneficial terrestrial organisms\nshowed that 9.6-39.1 \\% of samples posed a potential medium or high\necological risk, with 13.6-65.9 \\% of samples at n-expressionry\nsumexpressiontion RQ > 1 being highly affected by the residues of\nneonicotinoids and emamectin benzoate. Emamectin benzoate (8.9 \\%) and\nacetamiprid (5.6 \\%) exceeded the individual Maximum Residue Levels\nbased on of (2023) Chinese legislation (GB2763-2021). Moreover,\ncumulative dietary exposure presented a higher risk to humans in 11.0\nand 22.0 \\% of the cases for acute and chronic, mainly originating from\nthe higher concentration contributors of systemic pesticides in edible\ncrops. Therefore, the regulation and monitoring of CUP residues is\nimperative for rice -vegetable rotation systems in tropical China to\navoid negative effects on nontarget organisms.",
#   'Currently-used pesticides; Crops; Ecological risk; Dietary risk\nassessment; Hazard index',
#   '10.1016/j.scitotenv.2022.158640',
#   'Article; Early Access',
#   'NEONICOTINOID INSECTICIDES; ECOTOXICOLOGICAL RISK; SURFACE-WATER;\nHALF-LIVES; RESIDUES; DISSIPATION; VEGETABLES; MIXTURES; EXPOSURE;\nFARMERS'],
#  ['On the Use of NDVI to Estimate LAI in Field Crops: Implementing a\nConversion Equation Library',
#   "The leaf area index (LAI) is a direct indicator of vegetation activity,\nand its relationship with the normalized difference vegetation index\n(NDVI) has been investigated in many research studies. Remote sensing\nmakes available NDVI data over large areas, and researchers developed\nspecific equations to derive the LAI from the NDVI, using empirical\nrelationships grounded in field data collection. We conducted a\nliterature search using ``NDVI{''} AND ``LAI{''} AND ``crop{''} as the\nsearch string, focusing on the period 2017-2021. We reviewed the\navailable equations to convert the NDVI into the LAI, aiming at (i)\nexploring the fields of application of an NDVI-based LAI, (ii)\ncharacterizing the mathematical relationships between the NDVI and LAI\nin the available equations, (iii) creating a software library with the\nretrieved methods, and (iv) releasing a publicly available software as a\nservice, implementing these equations to foster their reuse by third\nparties. The literature search yielded 92 articles since 2017, where 139\nequations were proposed. We analyzed the mathematical form of both the\nsingle equations and ensembles of the NDVI to LAI conversion methods,\nspecific for crop, sensor, and biome. The characterization of the\nfunctions highlighted two main constraints when developing an NDVI-LAI\nconversion function: environmental conditions (i.e., water and light\nresource, land cover, and climate) and the availability of recurring\ndata during the growing season. We found that the trend of an NDVI-LAI\nfunction is usually driven by the ecosystem water availability for the\ncrop rather than by the crop type itself, as well as by the data\navailability; the data should be adequate in terms of the sample size\nand temporal resolution for reliably representing the phenomenon under\ninvestigation. Our study demonstrated that the choice of the NDVI-LAI\nequation (or ensemble of equations) should be driven by the trade-off\nbetween the scale of the investigation and data availability. The\nimplementation of an extensible and reusable software library publicly\nqueryable via API represents a valid mean to assist researchers in\nchoosing the most suitable equations to perform an NDVI-LAI conversion.",
#   'field crop; leaf area index; normalized difference vegetation index;\nremote sensing; SaaS; software component',
#   '10.3390/rs14153554',
#   'Article',
#   'LEAF-AREA INDEX; VEGETATION INDEXES; GREEN LAI; ABSORBED PAR; MODIS LAI;\nPRODUCTS; VALIDATION; MAIZE; WHEAT'],
#  ['Comparative Analysis of the Sensitivity of SAR Data in C and L Bands for\nthe Detection of Irrigation Events',
#   'Comprehensive knowledge about irrigation timing is crucial for water\nresource management. This paper presents a comparative analysis between\nC- and L-band Synthetic Aperture Radar (SAR) data for the detection of\nirrigation events. The analysis was performed using C-band time series\ndata derived from the Sentinel-1 (S1) satellite and two L-band images\nfrom the PALSAR-2 (ALOS-2) sensor acquired over irrigated grassland\nplots in the Crau plain of southeast France. The S1 C-band time series\nwas first analyzed as a function of rainfall and irrigation events. The\nbackscattering coefficients in both the L and C bands were then compared\nto the time difference between the date of the acquired SAR image and\nthe date of the last irrigation event occurring before the SAR\nacquisition (Delta t). Sensitivity analysis was performed for 2 classes\nof the Normalized Difference Vegetation Index (NDVI <= 0.7 and NDVI >\n0.7). The main results showed that when the vegetation is moderately\ndeveloped (NDVI <= 0.7), the C-band temporal variation remains sensitive\nto the soil moisture dynamics and the irrigation events could be\ndetected. The C-VV signal decreases due to the drying out of the soil\nwhen the time difference between the S1 image and irrigation event\nincreases. For well-developed vegetation cover (NDVI > 0.7), the C-band\nsensitivity to irrigation events becomes dependent on the crop type. For\nwell-developed Gramineae grass with longs stalks and seedheads, the C\nband shows no correlation with Delta t due to the absence of the soil\ncontribution in the backscattered signal, contrary to the legume grass\ntype, where the C band shows a good correspondence between C-VV and\nDelta t for NDVI > 0.7. In contrast, analysis of the L-band\nbackscattering coefficient shows that the L band remains sensitive to\nthe soil moisture regardless of the vegetation cover development and the\nvegetation characteristics, thus being more suitable for irrigation\ndetection than the C band. The L-HH signal over Gramineae grass or\nlegume grass types shows the same decreasing pattern with the increase\nin Delta t, regardless of the NDVI-values, presenting a decrease in soil\nmoisture with time and thus high sensitivity of the radar signal to soil\nparameters. Finally, the co-polarizations for both the C and L bands\n(L-HH and C-VV) tend to be more adequate for irrigation detection than\nthe HV cross-polarization, as they show higher sensitivity to soil\nmoisture values.',
#   'irrigation events; Synthetic Aperture Radar; Sentinel-1; ALOS-2',
#   '10.3390/rs14102312',
#   'Article',
#   'INTEGRAL-EQUATION MODEL; RADAR BACKSCATTER; SOIL-MOISTURE; TERRASAR-X;\nCALIBRATION; METHODOLOGY; SCATTERING; MAP'],
#  ['New Evidence on the Linkage of Population Trends and Species Traits to\nLong-Term Niche Changes',
#   "Simple Summary Temporal changes of ecological niches in relation to both\npopulation trends and species traits (life-history and ecological\ncharacteristics) are a poorly investigated topic in animal ecology even\nthough they can provide crucial information for investigating how\nspecies respond to ongoing environmental changes. To fill this gap, we\nassessed niche changes from 1992 to 2017 for 71 common breeding birds in\nNorthern Italy, using several niche metrics and relating them with both\npopulation trends and species traits. Our results showed that 32\\% of\nthe species tended to change their niche in relation to the accessible\nenvironmental conditions. We found a tendency to adjust the niche\ntowards warmer thermal conditions. This process may depend on several\ndrivers, which act differently across species. Species undergoing a\nniche expansion showed increasing populations, while species tending to\nretain their niche showed a tendency to be associated with decreasing\npopulations. We also found evidence for a non-random association between\nniche temporal changes and species traits. Investigating these\nrelationships is a pivotal point to implement effective conservation\nstrategies for wildlife.Abstract Despite the assessment of long-term\nniche dynamics could provide crucial information for investigating\nspecies responses to environmental changes, it is a poorly investigated\ntopic in ecology. Here, we present a case study of multi-species niche\nanalysis for 71 common breeding birds in Northern Italy, exploring\nlong-term niche changes from 1992 to 2017 and their relationship with\nboth population trends and species traits. We (i) quantified the\nrealized Grinnellian niche in the environmental space, (ii) compared\nvariations in niche breadth and centroid, (iii) tested niche divergence\nand conservatism through equivalency and similarity tests, (iv)\ncalculated niche temporal overlap, expansion and unfilling indices, and\n(v) investigated their association with both population changes and\nspecies traits. Results supported niche divergence (equivalency test)\nfor 32\\% of species, although two-thirds were not supported by the\nsimilarity test. We detected a general tendency to adjust the niche\ncentroids towards warmer thermal conditions. Increasing populations were\npositively correlated with niche expansion, while negatively correlated\nwith niche overlap, albeit at the limit of the significance threshold.\nWe found moderate evidence for a non-random association between niche\nchanges and species traits, especially for body size, clutch size,\nnumber of broods per year, inhabited landscape type, and migration\nstrategy. We encourage studies correlating long-term population trends\nand niche changes with species traits' information and a specific focus\non cause-effect relationship at both the single and multiple-species\nlevel.",
#   'breeding birds; migration strategy; farmland birds; niche conservatism;\nniche divergence; species specialization; body mass; ecospat',
#   '10.3390/birds3010011',
#   'Article',
#   'SKYLARKS ALAUDA-ARVENSIS; CLIMATE-CHANGE; BREEDING BIRDS; ECOLOGICAL\nNICHES; CROP TYPE; HABITAT; CONSERVATISM; SHIFTS; BIODIVERSITY;\nINVASIONS'],
#  ['Agrivoltaics in Color: Going From Light Spectra to Biomass',
#   "Agrivoltaics (AV), conceived in the early 1980s, promise to ameliorate\ncompetition between solar energy generation and crop production for\narable land. The premise behind AV is that excess light not used in\nphotosynthesis can be used for energy production. There are\nopportunities for maximizing photosynthesis by targeting particular\nwavelengths (e.g., red) to be transmitted through semi-transparent\nphotovoltaic (PV) cells depending on crop type and environmental\nconditions. Camporese and Abou Najm (2022, https://doi.\norg/10.1029/2022EF002900) developed a numerical model that accommodates\nthe various wavelengths of the incoming light spectrum to predict\nphotosynthesis, stomatal conductance, and transpiration. This commentary\nseeks to place those and other recent findings about the modifications\nto the plant micro-environment by PV cells in the context of maximum\nattainable aboveground biomass.\nPlain Language Summary With high demands for electricity and reduced\ncosts of solar panel manufacturing, competition for arable land between\nsolar energy production and crops comes as no surprise. A possible way\nforward to ameliorate the adverse effects of such competition is a\nsolution labeled as Agriphotovoltaics or simply Agrivoltaics (AV). AV is\nthe simultaneous use of land area for photovoltaic (PV) power generation\nand crop production. Crops are grown under elevated and fully opaque\nsolar panels so that the degree of shade and transmissible wavelengths\ncan be partly controlled. The premise of AV rests on the fact that\nplants require light to capture carbon dioxide from the atmosphere so as\nto produce biomass (including fruits, green leaves, roots, etc...). This\nprocess, known as photosynthesis, exhibits a saturation behavior-meaning\nbeyond some light level, increasing light does not enhance by much plant\nuptake of carbon dioxide molecules from the atmosphere. In the process\nof capturing one carbon dioxide molecule, plants also loose some 400\nwater molecules from their leaves, a process labeled as transpiration,\nthereby necessitating sustained water replenishment to the leaf from the\nsoil. The theoretical premise of AV is that the ``excess light{''} not\nused in photosynthesis may be used for energy production. Moreover, the\nevaporative cooling offered by transpiration can enhance the efficiency\nof solar panels to convert light to energy generation. Thus, the\nchallenge to AV is how to utilize these principles for maximizing crop\nproductivity, minimizing transpiration losses to reduce irrigation\nneeds, and maximizing photovoltaic energy generation. A necessary first\nstep to address this challenge requires the mathematical quantification\nof how crops utilize the various wavelengths of light in photosynthesis\nand, eventually, how these assimilated carbon dioxide molecules are\nconverted to crop yield. This commentary deals with aspects of this\nconversion using a mathematical framework known as dynamical systems\nwhere key dimensionless numbers that act as control parameter in future\ndesigns are identified.",
#   'agriphotovoltaics; dynamical systems; von Bartalenffy equation;\nbifurcation; photosynthesis; crop yield',
#   '10.1029/2023EF003512',
#   'Editorial Material',
#   'GROWTH; MODEL; CO2']]

# %%
identified_paper = pd.DataFrame(identified_paper)
# Specify the file path where you want to save the Excel file
file_path = 'paper_title.xlsx'
# Save the DataFrame to an Excel file
identified_paper.to_excel(file_path, index=False)  # Set index=False to exclude the DataFrame index in the output

# %%
len(identified_paper)
# Out:
# 53

# %% [markdown]
# ### ABSTRACT DATA EXTRAXTION

# %%
import pandas as pd
identified_paper = pd.read_excel('paper_title.xlsx')
rows_as_lists =[]
for index, row in identified_paper.iterrows():
    row_list = row.tolist()
    rows_as_lists.append(row_list)
identified_paper= rows_as_lists

# %%
# Select the 0th and 1st columns
selected_columns = [[row[0], row[1]] for row in identified_paper]

# Display the selected columns
print(selected_columns)
# Out:
# [['Drought versus flood: What matters more to the performance of Sahel\nfarming systems?', "Recent climate change has brought new patterns of extreme events in\nterms of both drought and heavy rainfall to the drought-prone African\nSahel. The effects of these recent extreme events on the performance of\nthe Sahel farming systems are still weakly investigated. This study aims\nat assessing effects of droughts versus floods on crop yield levels and\nlosses, focusing on the so-called recovery period, particularly\n2001-2020. A newly developed productivity-drought condition index (PDCI)\nis utilized to assess agricultural productivity as related to drought or\nflood in a highly vulnerable region, that is, the Sudanese Sahel. Four\nfarming systems, namely traditional rainfed, mechanized rainfed, gravity\nirrigated and spate irrigated systems, with sorghum and millet as staple\nfood crops, are considered. The PDCI is defined as a function of the\nintegrated normalized difference vegetation index (iNDVI) over the\ngrowing season. To address temporal and spatial variabilities, scaling\nof the PDCI is done in two dimensions: space and time. Crop statistics\nare used to derive yield losses. Our results show that both drought and\nflood episodes (seven and six episodes, respectively) can be captured\nusing the PDCI. Drought remains the most relevant risk to Sahel's crop\nproductivity. Some recent large-scale floods led to yield loss. However,\nfloods cause smaller risks to agricultural productivity compared to\ndroughts. Floods may even result in enhanced crop yields. Based upon\nscaling in the time or space domain, ranking the severity of drought\nimpacts on crop yield for individual years from 2001 to 2020 reveals\nleast to slightly different results. Vulnerability to drought depends on\nthe crop type and farming system. Drought effect on crop yield from the\nirrigated sector is clear on individual years but not as a general\nstatistical relationship. The parameter `percentage area under drought'\nexplains around one-third of the variation in the rainfed crop yield.\nThe spate irrigation scheme, the gravity irrigated system and the\nrainfed farmlands experienced respectively 87\\%, 57\\% and 46\\% of area\nunder drought on average. Irrigated systems produce much higher crop\nyields than rainfed systems. The mechanized system is more\ndrought-vulnerable than the traditional system. These results call for\nidentifying agricultural management pathways that recognize the combined\nimplications of both hydrological extremes for the region's food\nsecurity.\nA newly devised productivity-drought condition index (PDCI) based on\nintegrated normalized difference vegetation index (iNDVI) data is used\nto capture the performance of different Sahel farming systems. The\nperformance is evaluated spatially and temporally in a comparative study\nof effects of drought versus floods on crop yield levels and losses\nduring 2001-2020. Our research shows that: Crop productivity of all\nfarming systems is severely affected by drought; Flood events can also\nlead to a decline in productivity, but usually to a much lesser extent;\nThe vulnerability to droughts and floods depends upon the farming system\nand crop type. Our analysis shows that the farming systems in the\nSudanese Sahel have not reverted to conditions that could be described\nas a Sahel recovery. This study calls for agricultural management\ndecisions, which are specific for the different farming systems, in\nresponse to climate variability.image"], ["Arabic Semantic Similarity Approach for Farmers' Complaints", "Semantic similarity is applied for many areas in Natural Language\nProcessing, such as information retrieval, text classification,\nplagiarism detection, and others. Many researchers used semantic\nsimilarity for English texts, but few used for Arabic due to the\nambiguity of Arabic concepts in both sense and morphology. Therefore,\nthe first contribution in this paper is developing a  ...

# %%
import time
# Function to analyze abstract
def analyze_paper(text):
    # Preprocess text
       prompt=   f"""Given the  Abstract of a paper on crop classification and satellite imagery: {text},
              #Your task is to meticulously extract essential details.
              #Focus on identifying the Algorithm Details , Satellite Used, Crops Classified,Features Used and the Accuracy Measure.
              #It is crucial to present your findings in a uniform and structured format.
              #Return response in a Python list format, where each item is a dictionary with key-value pairs.
              #The keys should be ['Algorithm','Satellite','Features Used', 'Crops', 'Accuracy Measure'], and the values should be placeholders for the respective data.
              #Follow the outline provided and donot unneccasry details."""


       keywords = model.generate_content(prompt)
       print(keywords.text)
       return keywords.text


# Analyze abstarct and find keywords
theme_keywords = []
for row in selected_columns:
  try:
    theme_keywords.append(analyze_paper(row))
  except Exception as e:
        print(f"Error occurred: {e}")
        time.sleep(120)
        theme_keywords.append(analyze_paper(row))
# Out:
# ```python
# [
#   {
#     'Algorithm': 'Productivity-drought condition index (PDCI)',
#     'Satellite': 'Not Mentioned',
#     'Features Used': [
#       'Integrated normalized difference vegetation index (iNDVI)',
#       'Percentage area under drought'
#     ],
#     'Crops': [
#       'Sorghum',
#       'Millet'
#     ],
#     'Accuracy Measure': 'Not Mentioned'
#   }
# ]
# ```
# [
#     {
#         'Algorithm': 'MapReduce Support Vector Machine and Latent Semantic Analysis',
#         'Satellite': 'Not Mentioned',
#         'Features Used': 'Term Frequency and Term Frequency-Inverse Document Frequency',
#         'Crops': 'Not Specified',
#         'Accuracy Measure': 'F-measure of 86.7%'
#     }
# ]
# ```python
# details = [
#     {
#         'Algorithm': 'Not mentioned in the abstract',
#         'Satellite': 'Not mentioned in the abstract',
#         'Features Used': 'Not mentioned in the abstract',
#         'Crops': 'Rapeseed',
#         'Accuracy Measure': 'Not mentioned in the abstract'
#     }
# ]
# ```
# ```python
# [
#  {
#   'Algorithm': '``Mapping Evapotranspiration at high Resolution with\nInternalized Calibration'' methodology',
#   'Satellite': 'Landsat 7 and 8',
#   'Features Used': ["crop water stress index (CWSI)", "leaf area index (LAI)", "energy\nbalance components"],
#   'Crops': ['wheat', 'lettuce', 'potatoes'],
#   'Accuracy Measure': 'r 1/4 0.95 and r 1/4 0.99 for wheat and lettuce,\nrespectively; r 1/4 0.44 for potatoes in the winter season'
#  }
# ]
# ```
# ```python
# [
#   {
#     'Algorithm': 'Balanced Bagging classifier',
#     'Satellite': 'Not specified in the abstract',
#     'Features Used': 'Soil, climatic, and topographic parameters',
#     'Crops': 'Wheat and mustered',
#     'Accuracy Measure': 'Balanced accuracy of 97.69\\% and 97.57\\% for mustered and wheat crop suitability predictions, respectively, and a balanced accuracy of 97.36\\% for crop classification'
#   }
# ]
# ```
# Since the paper provided does not mention any algorithm, satellite data, crops classified, features used, or accuracy measures, I cannot extract the requested information. Therefore, the Python list you requested cannot be generated.
# ```python
# [
#     {
#         'Algorithm': 'Random Forest',
#         'Satellite': 'Sentinel-1',
#         'Features Used': 'Alpha angle, Polarimetric radar vegetation index, Timeseries SAR imagery',
#         'Crops': 'Groundnut, Cotton',
#         'Accuracy Measure': 'Overall Accuracy: 92.7%, Kappa Coefficient: 0.81'
#     }
# ]
# ```
# ```
# [
#    {
#        'Algorithm': None,
#        'Satellite': None,
#        'Features Used': None,
#        'Crops': ['Grapevine'],
#        'Accuracy Measure': None
#    }
# ]
# ```
# ```python
# [
#     {
#         'Algorithm': 'Not Mentioned',
#         'Satellite': 'Not Mentioned',
#         'Features Used': 'Not Mentioned',
#         'Crops': 'Brassica napus (winter oilseed rape)',
#         'Accuracy Measure': 'Not Mentioned'
#     }
# ]
# ```
# ```python
# [
#     {
#         'Algorithm': 'Machine Learning (ML) algorithms, e.g., Support Vector Regression (SVR), Random Forest (RF), Gradient Boosting (GB), and Extreme Gradient Boosting (XGB)',
#         'Satellite': 'Polarimetric Synthetic Aperture Radar (SAR) data and optical images',
#         'Features Used': 'Radar polarimetric features and Vegetation Indices (VIs)',
#         'Crops': 'soybean, corn, and canola',
#         'Accuracy Measure': 'Root Mean Square Error (RMSE)'
#     },
#     {
#         'Algorithm': 'Deep artificial neural network',
#         'Satellite': 'Polarimetric Synthetic Aperture Radar (SAR) data and optical images',
#         'Features Used': 'Radar polarimetric features and Vegetation Indices (VIs)',
#         'Crops': 'soybean, corn, and canola',
#         'Accuracy Measure': 'Not provided in the abstract'
#     }
# ]
# ```
# ```python
# [
#   {
#     'Algorithm': 'Change vector Analysis',
#     'Satellite': 'Sentinel-2A',
#     'Features Used': ['Canopy spectral reflectance','Vegetation index'],
#     'Crops': ['Rice (Oryza sativa L.)'],
#     'Accuracy Measure': 'R^2: 0.60-0.66, RMSE: 20.37-22.84%'
#   }
# ]
# ```
# ```
# details = [
#     {
#         'Algorithm': 'Not Provided',
#         'Satellite': 'Copernicus program: SAR Sentinel-1 and Sentinel-2',
#         'Features Used': 'Not Provided',
#         'Crops': 'Major crops',
#         'Accuracy Measure': 'Correlation coefficient (r) and coefficient of determination R-2'
#     },
# ]
# ```
# ```python
# [
#     {
#         'Algorithm': 'Modified Penman-Monteith method',
#         'Satellite': ['Landsat-8','MODIS'],
#         'Features Used': ['NDVI', 'Climatic data', 'DEM'],
#         'Crops': ['Not specified'],
#         'Accuracy Measure': 'Not specified'
#     }
# ]
# ```
# ```python
# [
#     {
#         'Algorithm': 'Not Mentioned',
#         'Satellite': 'Not Mentioned',
#         'Crops': ['Foxtail millet', 'Proso millet', 'Sorghum'],
#         'Features Used': ['Soil organic matter (OM)', 'Total nitrogen (TN)', 'pH'],
#         'Accuracy Measure': 'Not Mentioned'
#     }
# ]
# ```
# ```python
# [
#     {
#         'Algorithm': 'Not Mentioned',
#         'Satellite': 'Not Mentioned',
#         'Features Used': 'Not Mentioned',
#         'Crops': ['Rice (Oryza sativa L.)', 'Forage wheat (Triticum aestivum L. cv. Shimai-1)', 'Italian ryegrass (Lolium multiflorum L.)'],
#         'Accuracy Measure': 'Not Mentioned'
#     }
# ]
# ```
# ```python
# [
#   {
#     'Algorithm': 'Not mentioned in the context',
#     'Satellite': 'Not mentioned in the context',
#     'Features Used': 'Not mentioned in the context',
#     'Crops': ['Allium cepa L.'],
#     'Accuracy Measure': 'Not mentioned in the context'
#   }
# ]
# ```
# [{'Algorithm': 'CHANS model', 'Satellite': None, 'Features Used': ['Nitrogen deposition', 'straw recycling', 'biological nitrogen fixation (BNF)', 'chemical nitrogen fertilizer', 'manure inputs', 'temperature', 'precipitation', 'GDP', 'degree of urbanization'], 'Crops': ['Grain crops', 'vegetables'], 'Accuracy Measure': None}]
# ```python
# [
#     {
#         'Algorithm': 'Hilbert-Huang transform',
#         'Satellite': 'Not mentioned',
#         'Features Used': 'Axial vibration signals',
#         'Crops': 'Not mentioned',
#         'Accuracy Measure': 'Not provided'
#     }
# ]
# ```
# ```python
# [
#   {
#     'Algorithm' : 'Not Provided',
#     'Satellite': 'Not Provided',
#     'Features Used': 'Not Provided',
#     'Crops': 'Not Provided',
#     'Accuracy Measure': 'Not Provided',
#   }
# ]
# ```
# ```
# [
#   {
#     'Algorithm' : 'Not mentioned in the given abstract.',
#     'Satellite' : 'Not mentioned in the given abstract.',
#     'Features Used' : 'Not mentioned in the given abstract',
#     'Crops' : ["corn, pepper, cabbage, watermelon"],
#     'Accuracy Measure' : 'Not mentioned in the given abstract.'
#   }
# ]
# ```
# ```python
# details = [
#     # Algorithm Details
#     {
#         'Algorithm': 'Not Mentioned in the Abstract'
#     },
#
#     # Satellite Used
#     {
#         'Satellite': 'Not Mentioned in the Abstract'
#     },
#
#     # Crops Classified
#     {
#         'Crops': '23 Crop Types (Not Specified in the Abstract)'
#     },
#
#     # Features Used
#     {
#         'Features Used': 'Not Mentioned in the Abstract'
#     },
#
#     # Accuracy Measure
#     {
#         'Accuracy Measure': 'Not Mentioned in the Abstract'
#     }
# ]
# ```
# ```python
# [
#     {
#         'Algorithm': None,
#         'Satellite': None,
#         'Features Used': None,
#         'Crops': None,
#         'Accuracy Measure': None
#     },
# ]
# ```
# ```python
# [
#   {
#     "Algorithm": "Not mentioned in the abstract",
#     "Satellite": "Not mentioned in the abstract",
#     "Features Used": ["soil salinity", "acidity", "region", "type of crop"],
#     "Crops": ["forage crops", "vegetables", "industrial crops", "fruit trees", "cereals"],
#     "Accuracy Measure": "Not mentioned in the abstract"
#   }
# ]
# ```
# ```python
# [
#   {
#     "Algorithm": "NA",
#     "Satellite": "NA",
#     "Features Used": "NA",
#     "Crops": "NA",
#     "Accuracy Measure": "NA"
#   }
# ]
# ```
# ```python
# Details = [
#     {
#         'Algorithm': 'Not Mentioned',
#         'Satellite': 'Not Mentioned',
#         'Features Used': 'Carbon-to-nutrient ratios, pH, salt content electric conductivity, nitrogen N supply, crop type, soil texture, soil organic carbon, pH, temperature, rainfall',
#         'Crops': 'major cereal crops',
#         'Accuracy Measure': 'Not Mentioned'
#     }
# ]
# ```
# ```python
# [
#     {
#         'Algorithm': 'Not Mentioned',
#         'Satellite': 'Not Mentioned',
#         'Crops': 'Not Mentioned',
#         'Features Used': 'Not Mentioned',
#         'Accuracy Measure': 'Not Mentioned'
#     }
# ]
# ```
# ```python
# [
#     {
#         'Algorithm': 'Dynamic Stochastic Integrated Climate-Economic Spatiotemporal model',
#         'Satellite': 'Not specified',
#         'Features Used': ['Model-generated and observed climate/weather variables', 'Temperature', 'Precipitation', 'Agricultural variables', 'Crop allocations', 'Crop types', 'Land use', 'Crop rotation'],
#         'Crops': 'Not specified',
#         'Accuracy Measure': 'Not specified'
#     }
# ]
# ```
# ```python
# [
#     {
#         'Algorithm': 'Random Forest (RF)',
#         'Satellite': 'Not specified',
#         'Features Used': 'Land area, proportion of agricultural income, crop type, size of the labor force, identity, gender',
#         'Crops': 'Food crops, economic crops',
#         'Accuracy Measure': 'Overall prediction accuracy: 86.98%, Out-of-bag prediction error: 13.02%'
#     }
# ]
# ```
# ```python
# [
#     {
#         'Algorithm': 'Not Mentioned',
#         'Satellite': 'Not Mentioned',
#         'Features Used': 'Not Mentioned',
#         'Crops': ['Corn', 'Soybean'],
#         'Accuracy Measure': 'Not Mentioned'
#     }
# ]
# ```
# ```
# [
# {
# "Algorithm": "Random Forest (RF) and Support Vector Machine (SVM)",
# "Satellite": "Gaofen 6 (GF-6) satellite",
# "Features Used": "Multispectral bands, including seven classification classes: maize, buildings, woodlands, wastelands, water, roads, and other crops, as well as red-edge bands, purple band, and yellow band",
# "Crops": "Maize",
# "Accuracy Measure": "Not explicitly mentioned in the abstract"
# }]
# ```
# ```python
# [
#   {
#     'Algorithm': 'Spectral Mixture Analysis (SMA) ',
#     'Satellite': 'GF-1, Sentinel-2',
#     'Features Used': 'Normalized difference yellowness index (NDYI), enhanced vegetation index (EVI), renormalized difference VI (RDVI), normalized difference VI (NDVI), visible atmospherically resistant index (VARI), leaf abundance (AbdLF)',
#     'Crops': 'Rapeseed',
#     'Accuracy Measure': 'R2 above 0.78, CVs below 10%'
#   }
# ]
# ```
# ```python
# response_list = [
#     {
#         'Algorithm': 'Not mentioned in the provided abstract',
#         'Satellite': 'Not mentioned in the provided abstract',
#         'Features Used': 'Not mentioned in the provided abstract',
#         'Crops': ['Vegetables', 'Maize', 'Rice', 'Wheat'],
#         'Accuracy Measure': 'Not mentioned in the provided abstract'
#     }
# ]
# ```
# WARNING:tornado.access:429 POST /v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 810.85ms
# Error occurred: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-pro:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).
# ```
# [
#   {
#     'Algorithm': 'Not Mentioned',
#     'Satellite': 'Not Mentioned',
#     'Features Used': 'Soil organic carbon, Nitrogen, Soil texture',
#     'Crops': ['Cereals', 'Oil-producing crops', 'Orchards'],
#     'Accuracy Measure': 'Not Mentioned'
#   }
# ]
# ```
# ```python
# [
#   {
#     'Algorithm': 'Light Productivity Factor (LPF)',
#     'Satellite': 'Not mentioned in the abstract',
#     'Features Used': ['Photosynthetically active radiation needs of the crop', 'Spatial PV array density', 'Panel orientation', 'Single axis tracking scheme'],
#     'Crops': ['Shade-tolerant crops', 'Shade-sensitive crops'],
#     'Accuracy Measure': 'Not mentioned in the abstract'
#   }
# ]
# ```
# ```python
# [
#     {
#         'Algorithm': 'Not Mentioned',
#         'Satellite': 'Not Mentioned',
#         'Features Used': 'Not Mentioned',
#         'Crops': 'Not Mentioned',
#         'Accuracy Measure': 'Not Mentioned'
#     }
# ]
# ```
# ```
# [
#   {
#     "Algorithm": "Not Mentioned",
#     "Satellite": "Not Mentioned",
#     "Features Used": "Not Mentioned",
#     "Crops": ["Grain sorghum", "Sweet sorghum"],
#     "Accuracy Measure": "Not Mentioned"
#   }
# ]
# ```
# ```python
# [
#     {
#         'Algorithm': 'Not Mentioned in the Abstract',
#         'Satellite': 'Not Mentioned in the Abstract',
#         'Features Used': 'Not Mentioned in the Abstract',
#         'Crops': 'Not Mentioned in the Abstract',
#         'Accuracy Measure': 'Not Mentioned in the Abstract'
#     }
# ]
# ```
# ```python
# [
#     {
#         'Algorithm': 'Bottom-up method',
#         'Satellite': 'Not Mentioned',
#         'Features Used': ['Soil properties', 'Method of fertilizer application', 'Fertilizer type', 'Crop type', 'Ambient temperature', 'Wind speed'],
#         'Crops': 'Not Mentioned',
#         'Accuracy Measure': 'Not Mentioned'
#     }
# ]
# ```
# ```python
# [
#   {
#     'Algorithm': 'Not Mentioned',
#     'Satellite': 'Not Mentioned',
#     'Features Used': 'Not Mentioned',
#     'Crops': ['Cashew', 'Areca', 'Banana', 'Pulpy/Fleshy Fruits'],
#     'Accuracy Measure': 'Not Mentioned'
#   }
# ]
# ```
# ```python
# [
#     {
#         'Algorithm': 'AquaCrop Crop Model',
#         'Satellite': 'Not mentioned',
#         'Features Used': 'Canopy cover (CC), dry aboveground biomass (AGB), actual evapotranspiration (ETa), runoff (R), soil water content (SWC)',
#         'Crops': 'Not mentioned',
#         'Accuracy Measure': 'R-2 of 0.45 for CC, R-2 of 0.81 for AGB, R-2 of 0.62 for ETa, R-2 of 0.68 for R, R-2 of 0.86 for SWC'
#     }
# ]
# ```
# ```python
# [
#   {
#     'Algorithm': 'LiDAR data quality control and crop characterization framework',
#     'Satellite': 'Not mentioned in the abstract',
#     'Features Used': 'Terrain patches and row/alley locations',
#     'Crops': 'Not mentioned in the abstract',
#     'Accuracy Measure': 'Net vertical and planimetric discrepancies between multi-temporal point clouds: Vertical: ±3 cm, Planimetric: ±8 cm'
#   }
# ]
# ```
# ```
# extracted_details =  [
#     {
#         'Algorithm': None,
#         'Satellite': None,
#         'Features Used': 'Independent Variable - Reduction in solar radiation',
#         'Crops': ['Berries', 'Fruits', 'Fruity vegetables', 'Forages', 'Leafy vegetables', 'Tubers/root crops', 'C-3 cereals', 'Maize', 'Grain legumes'],
#         'Accuracy Measure': None
#     }
# ]
# ```
# ```python
# [
#     {
#         'Algorithm': 'Decision tree (DT)',
#     },
#     {
#         'Algorithm': 'Random forest (RF)',
#     },
#     {
#         'Algorithm': 'Artificial neural network (ANN)',
#     },
#     {
#         'Algorithm': 'Stacked-sparse autoencoder (SSAE)',
#     },
#     {
#         'Algorithm': 'Convolutional neural network (CNN)',
#     },
#     {
#         'Algorithm': 'Long short-term memory (LSTM)',
#         'Satellite': 'Moderate resolution imaging spectroradiometer (MODIS)',
#         'Features Used': ['Vegetation indices', 'Weather data', 'Crop yield statistics', 'Land cover map'],
#         'Crops': ['Paddy rice', 'Corn', 'Soybean'],
#         'Accuracy Measure': 'Root mean square error (RRMSE)',
#     },
#     {
#         'Algorithm': 'Support vector machine (SVM)',
#         'Satellite': 'Moderate resolution imaging spectroradiometer (MODIS)',
#         'Features Used': ['Vegetation indices', 'Weather data', 'Crop yield statistics', 'Land cover map'],
#         'Crops': ['Paddy rice', 'Corn', 'Soybean'],
#         'Accuracy Measure': 'Root mean square error (RRMSE)',
#     },
# ]
# ```
# ```python
# [
#   {
#     'Algorithm': 'Not Mentioned',
#     'Satellite': 'Not Mentioned',
#     'Features Used': ['Residue height', 'Diameter', 'Soil surface cover', 'Postharvest\nstanding stems', 'Stem diameters', 'Residue heights', 'Soil surface\ncoverage', 'Decomposition days (DD)', 'Soil cover measurements'],
#     'Crops': ['winter wheat (Triticum aestivum)', 'forage crop (Sorghum bicolor and\nSetaria italica)', 'wheat', 'forage sorghum', 'forage millet'],
#     'Accuracy Measure': 'Not Mentioned'
#   }
# ]
# ```
# ```python
# [
#   {
#     'Algorithm': 'Not mentioned in the abstract',
#     'Satellite': 'Not mentioned in the abstract',
#     'Features Used': 'Not mentioned in the abstract',
#     'Crops': 'Not mentioned in the abstract',
#     'Accuracy Measure': 'Not mentioned in the abstract'
#   }
# ]
# ```
# ```python
# [
#     {
#         'Algorithm': 'One-way analysis of variance and stepwise multiple linear regression',
#         'Satellite': 'Not mentioned in the abstract',
#         'Features Used': 'Climate, topography, soil properties, vegetation, and land use',
#         'Crops': 'Not mentioned in the abstract',
#         'Accuracy Measure': 'Not mentioned in the abstract'
#     }
# ]
# ```
# ```python
# [
#   {
#     'Algorithm': 'Not Mentioned',
#     'Satellite': 'Not Mentioned',
#     'Features Used': 'Water and Nitrogen Inputs',
#     'Crops': 'Wheat and Triticale',
#     'Accuracy Measure': 'Not Mentioned'
#   }
# ]
# ```
# ```python
# [
#   {
#     'Algorithm': 'APSIM crop growth simulation model',
#     'Satellite': 'Not mentioned in the abstract',
#     'Features Used': 'Biological variability in sorghum cultivar characteristics, range of farmer-relevant agronomic management practices, soil types (shallow, medium, and deep vertisols)',
#     'Crops': 'Sorghum',
#     'Accuracy Measure': 'Not mentioned in the abstract'
#   }
# ]
# ```
# ```python
# [
#     {
#         "Algorithm": "Not Provided",
#         "Satellite": "Not Provided",
#         "Features Used": "Not Provided",
#         "Crops": ["Rice", "Vegetables"],
#         "Accuracy Measure": "Not Provided",
#     }
# ]
# ```
# ```
# response = [
#     {
#         'Algorithm': 'NDVI-LAI conversion equation library',
#         'Satellite': 'Not specified in the provided abstract',
#         'Features Used': 'NDVI (Normalized Difference Vegetation Index)',
#         'Crops': 'Field crops (not specified in the provided abstract)',
#         'Accuracy Measure': 'Not specified in the provided abstract'
#     }
# ]
# ```
# ```python
# [
#   {
#     'Algorithm': 'Comparison of backscattering coefficients in C- and L-bands',
#     'Satellite': ['Sentinel-1 (S1)','PALSAR-2 (ALOS-2)'],
#     'Features Used': ['Normalized Difference Vegetation Index (NDVI)', 'Time difference between SAR image and last irrigation event (Delta t)'],
#     'Crops': ['Irrigated grassland plots', 'Gramineae grass', 'legume grass'],
#     'Accuracy Measure': 'Not specified in the abstract'
#   }
# ]
# ```
# The provided context does not contain information on crop classification, satellite imagery, or the details requested in the task. Therefore, I cannot extract the requested information from the provided context.
# ```python
# [
#     {
#         'Algorithm': 'Not Mentioned',
#         'Satellite': 'Not Mentioned',
#         'Features Used': 'Not Mentioned',
#         'Crops': 'Not Mentioned',
#         'Accuracy Measure': 'Not Mentioned',
#     }
# ]
# ```

# %%
def remove_before_substring(s, substring):
    index = s.find(substring)
    if index != -1:  # Check if the substring is found
        return s[index:]  # Slice from the substring to the end
    else:
        return s  # Return the original string if substring is not found

# %%
# Function to merge any number of lists of dictionaries
def merge_lists(*lists):
    merged_dict = {}
    for l in lists:
        for d in l:
            for key, value in d.items():
                if key in merged_dict:
                   if isinstance(value, list):
                        value = ', '.join(value)
                   merged_dict[key] += ', ' + value
                else:
                    merged_dict[key] = value
    return merged_dict

# %%
import ast
import json
response_list = []
i=0
for item in theme_keywords:
  data = item

  try:
    data = remove_before_substring(data,'[')
    data = data.replace("```", "").replace("```", "").strip()
  except Exception as e:
    print(e)
  finally:
    try:
      response = ast.literal_eval(data)
      if(len(response)>1):
        merged_dict = merge_lists(response)
      else:
        merged_dict = response[0]
    except Exception as e:
        print(i)
        #merged_dict = json.dumps(data)
        #merged_dict = ast.literal_eval(merged_dict)
    i =i+1
    response_list.append(merged_dict)
# Out:
# 5
# 51

# %%
import pandas as pd

# Assuming response_list is your list of lists
Final_list = pd.DataFrame(response_list)

# %%
display(Final_list)
# Out:
#                                             Algorithm  \
# 0         Productivity-drought condition index (PDCI)
# 1   MapReduce Support Vector Machine and Latent Se...
# 2                       Not mentioned in the abstract
# 3   ``Mapping Evapotranspiration at high Resolutio...
# 4                         Balanced Bagging classifier
# 5                         Balanced Bagging classifier
# 6                                       Random Forest
# 7                                                None
# 8                                       Not Mentioned
# 9   Machine Learning (ML) algorithms, e.g., Suppor...
# 10                             Change vector Analysis
# 11                                       Not Provided
# 12                    Modified Penman-Monteith method
# 13                                      Not Mentioned
# 14                                      Not Mentioned
# 15                       Not mentioned in the context
# 16                                        CHANS model
# 17                            Hilbert-Huang transform
# 18                                       Not Provided
# 19               Not mentioned in the given abstract.
# 20                      Not Mentioned in the Abstract
# 21                                               None
# 22                      Not mentioned in the abstract
# 23                                                 NA
# 24                                      Not Mentioned
# 25                                      Not Mentioned
# 26  Dynamic Stochastic Integrated Climate-Economic...
# 27                                 Random Forest (RF)
# 28                                      Not Mentioned
# 29  Random Forest (RF) and Support Vector Machine ...
# 30                   Spectral Mixture Analysis (SMA)
# 31             Not mentioned in the provided abstract
# 32                                      Not Mentioned
# 33                    Light Productivity Factor (LPF)
# 34                                      Not Mentioned
# 35                                      Not Mentioned
# 36                      Not Mentioned in the Abstract
# 37                                   Bottom-up method
# 38                                      Not Mentioned
# 39                                AquaCrop Crop Model
# 40  LiDAR data quality control and crop characteri...
# 41                                               None
# 42  Decision tree (DT), Random forest (RF), Artifi...
# 43                                      Not Mentioned
# 44                      Not mentioned in the abstract
# 45  One-way analysis of variance and stepwise mult...
# 46                                      Not Mentioned
# 47                 APSIM crop growth simulation model
# 48                                       Not Provided
# 49               NDVI-LAI conversion equation library
# 50  Comparison of backscattering coefficients in C...
# 51  Comparison of backscattering coefficients in C...
# 52                                      Not Mentioned
#
#                                             Satellite  \
# 0                                       Not Mentioned
# 1                                       Not Mentioned
# 2                       Not mentioned in the abstract
# 3                                     Landsat 7 and 8
# 4                       Not specified in the abstract
# 5                       Not specified in the abstract
# 6                                          Sentinel-1
# 7                                                None
# 8                                       Not Mentioned
# 9   Polarimetric Synthetic Aperture Radar (SAR) da...
# 10                                        Sentinel-2A
# 11  Copernicus program: SAR Sentinel-1 and Sentinel-2
# 12                                 [Landsat-8, MODIS]
# 13                                      Not Mentioned
# 14                                      Not Mentioned
# 15                       Not mentioned in the context
# 16                                               None
# 17                                      Not mentioned
# 18                                       Not Provided
# 19               Not mentioned in the given abstract.
# 20                      Not Mentioned in the Abstract
# 21                                               None
# 22                      Not mentioned in the abstract
# 23                                                 NA
# 24                                      Not Mentioned
# 25                                      Not Mentioned
# 26                                      Not specified
# 27                                      Not specified
# 28                                      Not Mentioned
# 29                          Gaofen 6 (GF-6) satellite
# 30                                   GF-1, Sentinel-2
# 31             Not mentioned in the provided abstract
# 32                                      Not Mentioned
# 33                      Not mentioned in the abstract
# 34                                      Not Mentioned
# 35                                      Not Mentioned
# 36                      Not Mentioned in the Abstract
# 37                                      Not Mentioned
# 38                                      Not Mentioned
# 39                                      Not mentioned
# 40                      Not mentioned in the abstract
# 41                                               None
# 42  Moderate resolution imaging spectroradiometer ...
# 43                                      Not Mentioned
# 44                      Not mentioned in the abstract
# 45                      Not mentioned in the abstract
# 46                                      Not Mentioned
# 47                      Not mentioned in the abstract
# 48                                       Not Provided
# 49             Not specified in the provided abstract
# 50               [Sentinel-1 (S1), PALSAR-2 (ALOS-2)]
# 51               [Sentinel-1 (S1), PALSAR-2 (ALOS-2)]
# 52                                      Not Mentioned
#
#                                         Features Used  \
# 0   [Integrated normalized difference vegetation i...
# 1   Term Frequency and Term Frequency-Inverse Docu...
# 2                       Not mentioned in the abstract
# 3   [crop water stress index (CWSI), leaf area ind...
# 4          Soil, climatic, and topographic parameters
# 5          Soil, climatic, and topographic parameters
# 6   Alpha angle, Polarimetric radar vegetation ind...
# 7                                                None
# 8                                       Not Mentioned
# 9   Radar polarimetric features and Vegetation Ind...
# 10    [Canopy spectral reflectance, Vegetation index]
# 11                                       Not Provided
# 12                         [NDVI, Climatic data, DEM]
# 13  [Soil organic matter (OM), Total nitrogen (TN)...
# 14                                      Not Mentioned
# 15                       Not mentioned in the context
# 16  [Nitrogen deposition, straw recycling, biologi...
# 17                            Axial vibration signals
# 18                                       Not Provided
# 19                Not mentioned in the given abstract
# 20                      Not Mentioned in the Abstract
# 21                                               None
# 22     [soil salinity, acidity, region, type of crop]
# 23                                                 NA
# 24  Carbon-to-nutrient ratios, pH, salt content el...
# 25                                      Not Mentioned
# 26  [Model-generated and observed climate/weather ...
# 27  Land area, proportion of agricultural income, ...
# 28                                      Not Mentioned
# 29  Multispectral bands, including seven classific...
# 30  Normalized difference yellowness index (NDYI),...
# 31             Not mentioned in the provided abstract
# 32        Soil organic carbon, Nitrogen, Soil texture
# 33  [Photosynthetically active radiation needs of ...
# 34                                      Not Mentioned
# 35                                      Not Mentioned
# 36                      Not Mentioned in the Abstract
# 37  [Soil properties, Method of fertilizer applica...
# 38                                      Not Mentioned
# 39  Canopy cover (CC), dry aboveground biomass (AG...
# 40            Terrain patches and row/alley locations
# 41  Independent Variable - Reduction in solar radi...
# 42  [Vegetation indices, Weather data, Crop yield ...
# 43  [Residue height, Diameter, Soil surface cover,...
# 44                      Not mentioned in the abstract
# 45  Climate, topography, soil properties, vegetati...
# 46                          Water and Nitrogen Inputs
# 47  Biological variability in sorghum cultivar cha...
# 48                                       Not Provided
# 49      NDVI (Normalized Difference Vegetation Index)
# 50  [Normalized Difference Vegetation Index (NDVI)...
# 51  [Normalized Difference Vegetation Index (NDVI)...
# 52                                      Not Mentioned
#
#                                                 Crops  \
# 0                                   [Sorghum, Millet]
# 1                                       Not Specified
# 2                                            Rapeseed
# 3                          [wheat, lettuce, potatoes]
# 4                                  Wheat and mustered
# 5                                  Wheat and mustered
# 6                                   Groundnut, Cotton
# 7                                         [Grapevine]
# 8                Brassica napus (winter oilseed rape)
# 9   soybean, corn, and canola, soybean, corn, and ...
# 10                           [Rice (Oryza sativa L.)]
# 11                                        Major crops
# 12                                    [Not specified]
# 13            [Foxtail millet, Proso millet, Sorghum]
# 14  [Rice (Oryza sativa L.), Forage wheat (Triticu...
# 15                                   [Allium cepa L.]
# 16                          [Grain crops, vegetables]
# 17                                      Not mentioned
# 18                                       Not Provided
# 19                [corn, pepper, cabbage, watermelon]
# 20      23 Crop Types (Not Specified in the Abstract)
# 21                                               None
# 22  [forage crops, vegetables, industrial crops, f...
# 23                                                 NA
# 24                                 major cereal crops
# 25                                      Not Mentioned
# 26                                      Not specified
# 27                         Food crops, economic crops
# 28                                    [Corn, Soybean]
# 29                                              Maize
# 30                                           Rapeseed
# 31                   [Vegetables, Maize, Rice, Wheat]
# 32           [Cereals, Oil-producing crops, Orchards]
# 33      [Shade-tolerant crops, Shade-sensitive crops]
# 34                                      Not Mentioned
# 35                     [Grain sorghum, Sweet sorghum]
# 36                      Not Mentioned in the Abstract
# 37                                      Not Mentioned
# 38       [Cashew, Areca, Banana, Pulpy/Fleshy Fruits]
# 39                                      Not mentioned
# 40                      Not mentioned in the abstract
# 41  [Berries, Fruits, Fruity vegetables, Forages, ...
# 42  [Paddy rice, Corn, Soybean, ,,  , P, a, d, d, ...
# 43  [winter wheat (Triticum aestivum), forage crop...
# 44                      Not mentioned in the abstract
# 45                      Not mentioned in the abstract
# 46                                Wheat and Triticale
# 47                                            Sorghum
# 48                                 [Rice, Vegetables]
# 49  Field crops (not specified in the provided abs...
# 50  [Irrigated grassland plots, Gramineae grass, l...
# 51  [Irrigated grassland plots, Gramineae grass, l...
# 52                                      Not Mentioned
#
#                                      Accuracy Measure
# 0                                       Not Mentioned
# 1                                  F-measure of 86.7%
# 2                       Not mentioned in the abstract
# 3   r 1/4 0.95 and r 1/4 0.99 for wheat and lettuc...
# 4   Balanced accuracy of 97.69\% and 97.57\% for m...
# 5   Balanced accuracy of 97.69\% and 97.57\% for m...
# 6    Overall Accuracy: 92.7%, Kappa Coefficient: 0.81
# 7                                                None
# 8                                       Not Mentioned
# 9   Root Mean Square Error (RMSE), Not provided in...
# 10                 R^2: 0.60-0.66, RMSE: 20.37-22.84%
# 11  Correlation coefficient (r) and coefficient of...
# 12                                      Not specified
# 13                                      Not Mentioned
# 14                                      Not Mentioned
# 15                       Not mentioned in the context
# 16                                               None
# 17                                       Not provided
# 18                                       Not Provided
# 19               Not mentioned in the given abstract.
# 20                      Not Mentioned in the Abstract
# 21                                               None
# 22                      Not mentioned in the abstract
# 23                                                 NA
# 24                                      Not Mentioned
# 25                                      Not Mentioned
# 26                                      Not specified
# 27  Overall prediction accuracy: 86.98%, Out-of-ba...
# 28                                      Not Mentioned
# 29           Not explicitly mentioned in the abstract
# 30                       R2 above 0.78, CVs below 10%
# 31             Not mentioned in the provided abstract
# 32                                      Not Mentioned
# 33                      Not mentioned in the abstract
# 34                                      Not Mentioned
# 35                                      Not Mentioned
# 36                      Not Mentioned in the Abstract
# 37                                      Not Mentioned
# 38                                      Not Mentioned
# 39  R-2 of 0.45 for CC, R-2 of 0.81 for AGB, R-2 o...
# 40  Net vertical and planimetric discrepancies bet...
# 41                                               None
# 42  Root mean square error (RRMSE), Root mean squa...
# 43                                      Not Mentioned
# 44                      Not mentioned in the abstract
# 45                      Not mentioned in the abstract
# 46                                      Not Mentioned
# 47                      Not mentioned in the abstract
# 48                                       Not Provided
# 49             Not specified in the provided abstract
# 50                      Not specified in the abstract
# 51                      Not specified in the abstract
# 52                                      Not Mentioned
